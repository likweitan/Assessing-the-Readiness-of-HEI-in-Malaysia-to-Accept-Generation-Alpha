# %% [markdown]
# # FINAL YEAR PROJECT

# %% [markdown]
# ## Overview
#
# 1. Introduction

# %% [markdown]
# ## 1 Introduction

# %% [markdown]
# ### 1.1 Background

# %% [markdown]
# ### 1.2 Data Description
#
# Dataset from https://www.kaggle.com/junyiacademy/learning-activity-public-dataset-by-junyi-academy
#
# **Acknowledgements**
#
# This dataset belongs to Junyi Academy and is publicly available for anyone to use under the following terms provided by the policy. Everyone using this dataset should follow the Creative Commons BY-NC-SA 4.0 license.
#
# <img src="https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F4924670%2F58e4b78490377106c07ab42f6fe4f6af%2F_LOGO-03.png?generation=1589354460688616&alt=media" alt="drawing" width="200"/>
#
# The authorized content does not include other intellectual properties including but not limited to the patents, trademark, and logo provided by Junyi Academy.
#
# Anyone using this dataset should not distort the information. Junyi Academy disclaims behaviors that may cause any possible damage to users of Junyi Academy. The person who caused the damage should be held responsible for compensation.
#
# Junyi Academy under reasonable conditions could ask the user of the dataset to share their feedback and research results with the community to encourage knowledge sharing and empower the education for the next generation.
#
# **Info_Content.csv**
#
# The content in Junyi Academy contains exercises, videos, and exams.
# All the content in this dataset is in the type of exercise.
#
# An exercise is a basic unit for students to learn a certain concept.
# There are multiple problems in a single exercise that all relate to a certain concept.
#
# This table records the metadata and hierarchy structure of each exercise in Junyi Academy.
# There are three difficulty settings for each content, which indicates how hard it is to learn the concept.
# The learning stage is separated into three stages: Elementary, Junior, and Senior.
#
# The exercises in Junyi Academy are organized in a tree-like structure.
# The current dataset release has four levels in the hierarchy.
#
# | Variable Name | Description |
# |:-|:-|
# | ucid | The hashed unique ID of the content. |
# | content_pretty_name | The Chinese display name of this content. |
# | content_kind | The kind of this content. The current dataset release only includes `Exercise` |
# | difficulty | The difficulty of this content. There are four possible values: `Easy`, `Normal`, `Hard` and `Unset`. Unset means |
# | learning stage | The subject of this content. The current dataset release only includes `math` |
# | subject | The learning stage of this content. There are three possible values: `Elementary`, `Junior` and `Senior`. |
# | level1_id | The hashed level 1 layer ID of this content. The levels form the tree-like hierarchy structure of contents in Junyi |
# | level2_id | The hashed level 2 layer ID of this content. The levels form the tree-like hierarchy structure of contents in Junyi |
# | level3_id | The hashed level 3 layer ID of this content. The levels form the tree-like hierarchy structure of contents in Junyi |
# | level4_id | The hashed level 4 layer ID of this content. The levels form the tree-like hierarchy structure of contents in Junyi |
#
# **Info_UserData.csv**
#
# This table contains the metadata for the 72,758 select users for this dataset
#
# All of the select users are students who meet the following filtering criteria:
#
# The registered date is between 2018-08-01 and 2019-07-31
# User grade is between 1 and 12
# User city is not null
# Energy Points are earned from Junyi Academy after completing exercises, watching videos, and when the user receives a badge.
#
# A user earns 750 * (effective watching time / video length) energy points after watching a video.
# (Effective watching time for a 10-minute video at 2X speed will be only 5-minute)
#
# A user earns a base of 75 energy points after completing an exercise at level 0.
# (Details of the leveling system will be described in the Proficiency Mechanism Section in Log_Problem's description)
#
# This might increase to at most 225 due to fast answering speed or repeated correct attempts.
# The points earned will decrease to as few as 5 as the user's level of that exercise increase to encourage the user to practice other exercises.
#
# The users might have teachers that can assign exercises to a student and look at the progress and results of the assignments.
# The student can also add himself/herself as a teacher of their own or other students.
# Classes are a group of students with a certain teacher.
#
# | Variable Name | Description |
# |:-|:-|
# | uuid | The unique ID of this user |
# | gender | The gender of this user. There are four possible values: `male`, `female`, `unspecified` and `null`. |
# | points | The user will receive energy points from the Junyi Academy after completing exercises, watching videos, and when the user receives a badge. |
# | badges_cnt | Badges are awarded to the users when the user achieves certain conditions. |
# | first_login_date_TW | The first login date after the user registers to Junyi Academy. |
# | user_grade | The grade of the user. The possible values are between 1 and 12. |
# | user_city | The resident city of the user. |
# | has_teacher_cnt | The number of teachers this user has in the Junyi Academy. |
# | is_self_coach | Does the user add himself/herself as a teacher of their own? |
# | has_student_cnt | The number of students this user has in the Junyi Academy. Despite the user role of this user is a student, this user can still add another user as a student. |
# | belongs_to_class_cnt | The number of classes this user belongs to. |
# | has_class_cnt | The number of classes this user created to add other users. Despite the user role of this user is a student, this user can still create a class to add other users in. |
#
# **Log_Problem.csv**
#
# An exercise is a basic unit for students to learn a certain concept.
# There are multiple problems in a single exercise that all relate to a certain concept.
#
# This table records the attempt logs when students try to answer each problem.
#
# The attempt timestamp is rounded to the closest 15-minute interval to reduce privacy concerns.
# The uuid and ucid can be used to join the other tables (InfoUserData, InfoContent)
#
# The problem_number refers to the number of problems the user had attempted including this attempt in this exercise.
# The exercise_problem_repeat_session refers to the number of times the user encounters this problem in this exercise.
#
# We define the answer to be correct when the user answered the correct answer the first time and does not use any hints.
# There are hints that the student can use that provides a step-by-step guide to get the correct answer.
# Each time a student uses a hint, a step of the step-by-step guide is shown.
#
# The Proficiency Mechanism
# According to the forgetting curve proposed by psychologist Hermann Ebbinghaus, by doing spaced repetition review in learning, we can improve the memory of the newly learned concepts and knowledge.
#
# To achieve this, Junyi Academy used the "Proficiency Mechanism" to encourage students to come back and review at regular intervals.
# The "Proficiency Mechanism" allows students to convert short-term memory into long-term memory through appropriate and repeated review.
#
# There are five possible levels, all users start from level 0 and progress to level 4 which we considered Proficient for that exercise.
#
# To reach level 1, the user will have to answer the problems correctly 5 times in the recent 6 problems attempts in the exercise.
#
# After reaching level 1, the user is required to wait 6 hours before he/she is able to attempt to level up again to level 2.
#
# After the waiting, the user will answer 2 problems from the exercise. For example, the user is at level 2 and get a chance to answer 2 problems:
#
# - If both are correct, the user is upgraded to level 3.
# - If both are incorrect, the user is downgraded to level 1.
# - If one of them is correct and one of them is incorrect, the level is unchanged and the user is prompted to try again the challenge.
#
# The procedure to upgrade or downgrade is the same for the other levels. But users will not be downgraded at level 1 or when the user reaches level 4 Proficient.
#
# After reaching level 2, the user is required to wait 16 hours before he/she is able to attempt to level up again to level 3.
#
# After reaching level 3, the user is required to wait 40 hours before he/she is able to attempt to level up again to level 4, which is the final level and considered Proficient for that exercise.
#
# | Variable Name | Description |
# |:-|:-|
# | timestamp_TW | The timestamp of the first behavior, answered the problem or used a hint. It is in UTC+8 timezone and rounded to the closest 15 mins interval to preserve privacy. |
# | uuid | The unique ID of the user. It can be used to join with Info_UserData. |
# | ucid | The unique ID of the content. It can be used to join with Info_Content. |
# | upid | The unique ID of the problem. |
# | problem_number | The number of problems this user had encountered, including this problem, in this exercise. |
# | exercise_problem_repeat_session | The number of times the user encounters this problem in this exercise |
# | is_correct | Whether the answer is considered correct or not. Only if the student answered the correct answer for the first time will it be `TRUE`. If the student used a hint or answered the wrong answer for the first time, it will be `FALSE`. |
# | total_sec_taken | How many seconds the user use for this problem encounter |
# | total_attempt_cnt | How many times have the user submitted an answer for this problem encounter |
# | used_hint_cnt | How many hints the user have used for this problem encounter |
# | is_hint_used | Whether the user use a hint or not. |
# | is_downgrade | After this attempt, is the user upgraded to the next level? Please refer to the detailed data description for the Proficiency Mechanism. |
# | is_upgrade | After this attempt, is the user downgraded to the next level? Please refer to the detailed data description for the Proficiency Mechanism. |
# | level | After this attempt, which level does this user belong to in this exercise? There are five possible levels. All users start from level 0 and declare Proficient at level 4. Please refer to the detailed data description for the Proficiency Mechanism. |

# %% [markdown]
# ### 1.3 Problem Statement

# %% [markdown]
# ## 2 Importing Data
#
# Data can come from a variety of sources. You can import CSV files from your local machine, query SQL servers, or use a web scraper to strip data from the Internet. I like to use the Python library, Pandas, to import data. Pandas is a great open-source data analysis library. We will also be using Pandas in the data cleaning step of this workflow.

# %% [markdown]
# ### 2.1 Importing the Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx
import pymongo
from googletrans import Translator # Google translate
import re #search regex
from datetime import datetime

# %%
def get_category_name(category_id):
    for category, id_ in category_codes.items():    
        if id_ == category_id:
            return category

# %%
def trim_outliers(df, variable):
    p01=school[variable].quantile(q=0.01)
    p99=school[variable].quantile(q=0.99)
    
    school.ix[(school[variable]<p01) | (school[variable]>p99), variable]=np.nan

# %% [markdown]
# ### Import the Datasets

# %%
# %%time
raw_df_InfoUser = pd.read_csv('data/Info_UserData.csv', index_col=0)
raw_df_LogProblem = pd.read_csv('data/Log_Problem.csv')
raw_df_InfoContent = pd.read_csv('data/Info_Content.csv', index_col=0)
# Out:
# Wall time: 2min 35s

# %%
# set seed for reproducibility
np.random.seed(0)

# %%
df_InfoUser = raw_df_InfoUser.copy()
df_LogProblem = raw_df_LogProblem.copy()
df_InfoContent = raw_df_InfoContent.copy()

# %%
# scale down some records
df_LogProblem = df_LogProblem[df_LogProblem['timestamp_TW'] < '2019-01-01']

# %%
#df_LogProblem[df_LogProblem['timestamp_TW'] >= '2019-01-01'].shape

# %%
7197409+9019902
# Out:
# 16217311

# %%
df_InfoUser.head()
# Out:
#                                              gender  points  badges_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=    NaN   18300           1
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=    NaN    6468           0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=   male    4703           0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=    NaN   15525           1
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=    NaN    7945           0
#
#                                              first_login_date_TW  user_grade  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=          2019-01-24           1
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=          2019-01-24           1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=          2019-01-24           1
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=          2019-01-24           2
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=          2019-01-24           2
#
#                                              user_city  has_teacher_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=        kh                0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=      ntpc                1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=        tp                0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=      ntpc                0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=        km                1
#
#                                               is_self_coach  has_student_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=          False                0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=          False                0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=          False                0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=          False                0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=          False                0
#
#                                               belongs_to_class_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=                     0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=                     1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=                     0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=                     0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=                     1
#
#                                               has_class_cnt
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=              0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=              0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=              0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=              0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=              0

# %%
df_InfoUser.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 72758 entries, Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ= to hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   gender                32905 non-null  object
#  1   points                72758 non-null  int64
#  2   badges_cnt            72758 non-null  int64
#  3   first_login_date_TW   72758 non-null  object
#  4   user_grade            72758 non-null  int64
#  5   user_city             72758 non-null  object
#  6   has_teacher_cnt       72758 non-null  int64
#  7   is_self_coach         72758 non-null  bool
#  8   has_student_cnt       72758 non-null  int64
#  9   belongs_to_class_cnt  72758 non-null  int64
#  10  has_class_cnt         72758 non-null  int64
# dtypes: bool(1), int64(7), object(3)
# memory usage: 8.7+ MB

# %%
# TODO: Calculate number of students
n_students = len(df_InfoUser)

# TODO: Calculate number of features
n_features = len(df_InfoUser.columns)

# TODO: Calculate passing students
n_passed = len(df_InfoUser.loc[df_InfoUser.user_grade > 0])

# TODO: Calculate failing students
n_failed = len(df_InfoUser.loc[df_InfoUser.user_grade <= 1])

# TODO: Calculate graduation rate
grad_rate = float(n_passed)/float(n_students) * 100

# Print the results
print ("Total number of students: {}".format(n_students))
print ("Number of features: {}".format(n_features))
print ("Number of students who passed: {}".format(n_passed))
print ("Number of students who failed: {}".format(n_failed))
print ("Graduation rate of the class: {:.2f}%".format(grad_rate))
# Out:
# Total number of students: 72758
# Number of features: 11
# Number of students who passed: 72758
# Number of students who failed: 1388
# Graduation rate of the class: 100.00%

# %%
df_LogProblem.head()
# Out:
#                  timestamp_TW                                          uuid  \
# 6814  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 6815  2018-09-28 10:15:00 UTC  0+VU/Zb0Q96uoByuRhl7r9bJuJO6CKWpsmNMEuijSzc=
# 6816  2018-09-05 20:00:00 UTC  g8DnYvIqpolw10XlwWeIWv6NbDPByUbmgH8EshJqBns=
# 6817  2018-09-14 16:30:00 UTC  kSyUTFlepsYUD723IPL/jEZ520xaKbscrBmNtBUFR1o=
# 6818  2018-09-13 16:00:00 UTC  XMFbFA7C49+LRhUddhelfPpA6F5dbOoxeyL3eYbuTlY=
#
#                                               ucid  \
# 6814  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 6815  /d39FzqaM3PZzpoMXxA80PMICsVhzfL6MGSCqZtsQOo=
# 6816  YuGOmB+frbM8rfAa0RJE882R+IoMf9N89OiVqLbAHBw=
# 6817  BG1RsWojzEHzV28RBm/1iKi1NyZgDcDomLYEJSV6lmo=
# 6818  qPHR8aBqOhKij9IS/Y8IR8prwWruoDBGU1tVUhXDJkE=
#
#                                               upid  problem_number  \
# 6814  ZmKEZ0F2WFqhlL7KFfJcHEnZCZu0e4p+CVG5rSlyKYk=               2
# 6815  tO9dyvadKWMVQgEx/BXtRIYJ2TRJFQgwvcsBwFb4+xI=               6
# 6816  6Lxz6aXvgyw3vZd3v8g6jgoCRDPOQzVPx/dnEC0o7DQ=               4
# 6817  1fIjdakTApQp5PfWog87uOmM6JuoNE/oQq2y5/fMmfw=               3
# 6818  8V/NT6M+er2I3V3ZIWRNo4Qbo3Iad89PHbeeZeoZeF0=              12
#
#       exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 6814                                1        True               11
# 6815                                1        True               26
# 6816                                1        True               78
# 6817                                1        True                7
# 6818                                1        True               48
#
#       total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade is_upgrade  \
# 6814                  1              0         False          NaN        NaN
# 6815                  1              0         False          NaN        NaN
# 6816                  1              0         False          NaN        NaN
# 6817                  1              0         False          NaN        NaN
# 6818                  1              0         False        False       True
#
#       level
# 6814      0
# 6815      0
# 6816      0
# 6817      0
# 6818      1

# %%
df_InfoContent.head()
# Out:
#                                              content_pretty_name content_kind  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=       【基礎】怎樣解題：數量關係     Exercise
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=          【基礎】和差問題 1     Exercise
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=          【基礎】雞兔問題 1     Exercise
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=          【基礎】年齡問題 1     Exercise
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=            【基礎】追趕問題     Exercise
#
#                                              difficulty subject  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=       easy    math
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=       easy    math
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=       easy    math
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=       easy    math
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=       easy    math
#
#                                              learning_stage  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=     elementary
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=     elementary
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=     elementary
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=     elementary
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=     elementary
#
#                                                                                  level1_id  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
#
#                                                                                  level2_id  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
#
#                                                                                  level3_id  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
#
#                                                                                  level4_id
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=

# %% [markdown]
# ### 3.1 Handling Missing Values
# The first thing to do when you get a new dataset is take a look at some of it. This lets you see that it all read in correctly and gives an idea of what's going on with the data. In this case, let's see if there are any missing values, which will be reprsented with NaN or None.

# %% [markdown]
# - Info User

# %%
df_InfoUser.head(5)
# Out:
#                                              gender  points  badges_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=    NaN   18300           1
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=    NaN    6468           0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=   male    4703           0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=    NaN   15525           1
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=    NaN    7945           0
#
#                                              first_login_date_TW  user_grade  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=          2019-01-24           1
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=          2019-01-24           1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=          2019-01-24           1
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=          2019-01-24           2
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=          2019-01-24           2
#
#                                              user_city  has_teacher_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=        kh                0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=      ntpc                1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=        tp                0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=      ntpc                0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=        km                1
#
#                                               is_self_coach  has_student_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=          False                0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=          False                0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=          False                0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=          False                0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=          False                0
#
#                                               belongs_to_class_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=                     0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=                     1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=                     0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=                     0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=                     1
#
#                                               has_class_cnt
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=              0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=              0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=              0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=              0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=              0

# %% [markdown]
# Ok, now we know that we do have some missing values. Let's see how many we have in each column.

# %%
# get the number of missing data points per column
missing_values_count = df_InfoUser.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count
# Out:
# gender                  39853
# points                      0
# badges_cnt                  0
# first_login_date_TW         0
# user_grade                  0
# user_city                   0
# has_teacher_cnt             0
# is_self_coach               0
# has_student_cnt             0
# belongs_to_class_cnt        0
# has_class_cnt               0
# dtype: int64

# %% [markdown]
# That seems like a lot! It might be helpful to see what percentage of the values in our dataset were missing to give us a better sense of the scale of this problem:

# %%
# how many total missing values do we have?
total_cells = np.product(df_InfoUser.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 4.979521152313147

# %%
# replace all NA's with unspecified
df_InfoUser.fillna('unspecified')
# Out:
#                                                    gender  points  badges_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=  unspecified   18300           1
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=  unspecified    6468           0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=         male    4703           0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=  unspecified   15525           1
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=  unspecified    7945           0
# ...                                                   ...     ...         ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=  unspecified    2393           2
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=  unspecified    1283           0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=  unspecified    5059           2
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=       female   17030           2
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=       female  293891          35
#
#                                              first_login_date_TW  user_grade  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=          2019-01-24           1
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=          2019-01-24           1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=          2019-01-24           1
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=          2019-01-24           2
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=          2019-01-24           2
# ...                                                          ...         ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=          2019-01-23          10
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=          2019-01-23          10
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=          2019-01-23          10
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=          2019-01-23          11
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=          2019-01-23          12
#
#                                              user_city  has_teacher_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=        kh                0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=      ntpc                1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=        tp                0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=      ntpc                0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=        km                1
# ...                                                ...              ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=        tc                1
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=       chc                0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=        tp                0
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=        tp                0
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=        tp                0
#
#                                               is_self_coach  has_student_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=          False                0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=          False                0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=          False                0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=          False                0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=          False                0
# ...                                                     ...              ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=          False                0
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=          False                0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=          False                0
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=          False                0
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=          False                0
#
#                                               belongs_to_class_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=                     0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=                     1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=                     0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=                     0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=                     1
# ...                                                            ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=                     1
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=                     0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=                     0
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=                     0
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=                     0
#
#                                               has_class_cnt
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=              0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=              0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=              0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=              0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=              0
# ...                                                     ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=              0
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=              0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=              0
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=              0
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=              0
#
# [72758 rows x 11 columns]

# %% [markdown]
# - Log Problem

# %%
df_LogProblem.head(5)
# Out:
#                  timestamp_TW                                          uuid  \
# 6814  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 6815  2018-09-28 10:15:00 UTC  0+VU/Zb0Q96uoByuRhl7r9bJuJO6CKWpsmNMEuijSzc=
# 6816  2018-09-05 20:00:00 UTC  g8DnYvIqpolw10XlwWeIWv6NbDPByUbmgH8EshJqBns=
# 6817  2018-09-14 16:30:00 UTC  kSyUTFlepsYUD723IPL/jEZ520xaKbscrBmNtBUFR1o=
# 6818  2018-09-13 16:00:00 UTC  XMFbFA7C49+LRhUddhelfPpA6F5dbOoxeyL3eYbuTlY=
#
#                                               ucid  \
# 6814  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 6815  /d39FzqaM3PZzpoMXxA80PMICsVhzfL6MGSCqZtsQOo=
# 6816  YuGOmB+frbM8rfAa0RJE882R+IoMf9N89OiVqLbAHBw=
# 6817  BG1RsWojzEHzV28RBm/1iKi1NyZgDcDomLYEJSV6lmo=
# 6818  qPHR8aBqOhKij9IS/Y8IR8prwWruoDBGU1tVUhXDJkE=
#
#                                               upid  problem_number  \
# 6814  ZmKEZ0F2WFqhlL7KFfJcHEnZCZu0e4p+CVG5rSlyKYk=               2
# 6815  tO9dyvadKWMVQgEx/BXtRIYJ2TRJFQgwvcsBwFb4+xI=               6
# 6816  6Lxz6aXvgyw3vZd3v8g6jgoCRDPOQzVPx/dnEC0o7DQ=               4
# 6817  1fIjdakTApQp5PfWog87uOmM6JuoNE/oQq2y5/fMmfw=               3
# 6818  8V/NT6M+er2I3V3ZIWRNo4Qbo3Iad89PHbeeZeoZeF0=              12
#
#       exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 6814                                1        True               11
# 6815                                1        True               26
# 6816                                1        True               78
# 6817                                1        True                7
# 6818                                1        True               48
#
#       total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade is_upgrade  \
# 6814                  1              0         False          NaN        NaN
# 6815                  1              0         False          NaN        NaN
# 6816                  1              0         False          NaN        NaN
# 6817                  1              0         False          NaN        NaN
# 6818                  1              0         False        False       True
#
#       level
# 6814      0
# 6815      0
# 6816      0
# 6817      0
# 6818      1

# %%
# get the number of missing data points per column
missing_values_count = df_LogProblem.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count
# Out:
# timestamp_TW                             0
# uuid                                     0
# ucid                                     0
# upid                                     0
# problem_number                           0
# exercise_problem_repeat_session          0
# is_correct                               0
# total_sec_taken                          0
# total_attempt_cnt                        0
# used_hint_cnt                            0
# is_hint_used                             0
# is_downgrade                       6365746
# is_upgrade                         6365746
# level                                    0
# dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(df_LogProblem.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 12.634995256130166

# %%
# replace all NA's with false
df_InfoUser.fillna('false')
# Out:
#                                               gender  points  badges_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=   false   18300           1
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=   false    6468           0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=    male    4703           0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=   false   15525           1
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=   false    7945           0
# ...                                              ...     ...         ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=   false    2393           2
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=   false    1283           0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=   false    5059           2
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=  female   17030           2
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=  female  293891          35
#
#                                              first_login_date_TW  user_grade  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=          2019-01-24           1
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=          2019-01-24           1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=          2019-01-24           1
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=          2019-01-24           2
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=          2019-01-24           2
# ...                                                          ...         ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=          2019-01-23          10
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=          2019-01-23          10
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=          2019-01-23          10
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=          2019-01-23          11
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=          2019-01-23          12
#
#                                              user_city  has_teacher_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=        kh                0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=      ntpc                1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=        tp                0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=      ntpc                0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=        km                1
# ...                                                ...              ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=        tc                1
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=       chc                0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=        tp                0
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=        tp                0
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=        tp                0
#
#                                               is_self_coach  has_student_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=          False                0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=          False                0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=          False                0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=          False                0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=          False                0
# ...                                                     ...              ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=          False                0
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=          False                0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=          False                0
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=          False                0
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=          False                0
#
#                                               belongs_to_class_cnt  \
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=                     0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=                     1
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=                     0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=                     0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=                     1
# ...                                                            ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=                     1
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=                     0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=                     0
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=                     0
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=                     0
#
#                                               has_class_cnt
# uuid
# Y2RcCdmUJAYPUAIDElo4nE9KrkLLFzUIRdexG+ipaZQ=              0
# lw/Rchfvl9q1UDaQRmeE6QJDJeXAK7nt56RvUvqxD/8=              0
# ncVYyCw3osV77X9M+4NbI7LvBR5UiB4ix6Ca+baQArA=              0
# J7Tbo1x2WtRpPuXeX7lWT9tkzWlSJeubl8UWjNmHh+4=              0
# qijKzROzz1LmCaCxHJ3mOBOtjW/q4kW80tnpPmXHVYQ=              0
# ...                                                     ...
# ESAeVlIpxgtgb2EtZb8K+plFLqKch5ffAgRzKnQqTQ4=              0
# DBQkIr4grFmnG2Aml3+haxfHbxp0kgerOxJfJ9JEWpE=              0
# 2KR+J0mQ2231WhAzulTMJ7ZuyKj43bPYbSdefVwOeQc=              0
# BAhs3hEK/PGa1ccNoEahYZsn+dOwRT3tPiojc34vMjQ=              0
# hkZZTOTi9MpjU38ctwOSK3O4g12JZt2ykeYS7nJsJkc=              0
#
# [72758 rows x 11 columns]

# %%
df_InfoContent.head(5)
# Out:
#                                              content_pretty_name content_kind  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=       【基礎】怎樣解題：數量關係     Exercise
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=          【基礎】和差問題 1     Exercise
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=          【基礎】雞兔問題 1     Exercise
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=          【基礎】年齡問題 1     Exercise
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=            【基礎】追趕問題     Exercise
#
#                                              difficulty subject  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=       easy    math
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=       easy    math
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=       easy    math
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=       easy    math
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=       easy    math
#
#                                              learning_stage  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=     elementary
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=     elementary
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=     elementary
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=     elementary
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=     elementary
#
#                                                                                  level1_id  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
#
#                                                                                  level2_id  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=  ICgke8JJv5eapCPwyj1aco8PEtoBkUbTZYIqxmYtqBk=
#
#                                                                                  level3_id  \
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=  bo3jsx1beVLEZ+2sckxdZNYnlLpVS7hb5lWU2baQ66k=
#
#                                                                                  level4_id
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=  KPJMQebU0O24+NzlQ4udb2BXLlKV1Hte61+hV5Xb+oU=

# %%
# get the number of missing data points per column
missing_values_count = df_InfoContent.isnull().sum()

# look at the # of missing points in the first ten columns
missing_values_count
# Out:
# content_pretty_name    0
# content_kind           0
# difficulty             0
# subject                0
# learning_stage         0
# level1_id              0
# level2_id              0
# level3_id              0
# level4_id              0
# dtype: int64

# %%
# how many total missing values do we have?
total_cells = np.product(df_InfoContent.shape)
total_missing = missing_values_count.sum()

# percent of data that is missing
percent_missing = (total_missing/total_cells) * 100
print(percent_missing)
# Out:
# 0.0

# %% [markdown]
# There is no missing values for the Info Content dataset, nothing has been changed.

# %% [markdown]
# ### Handling Text

# %%
df_InfoContent['content_pretty_name'].tail(5)
# Out:
# ucid
# NPkrCjbLK35wefMCv6y6XMO5eYO/gthS6LGwrdjG2OQ=     【進階】平方公分綜合習題
# 3xqxJN2W+KEo3SBjh7HnXpGjB4ewSbm1j/18fCn05yc=    【進階】周長與面積綜合習題
# j4rGpwpqhLE9foelXD2yjokS0u3QR+ULhNqLGeF/4sk=     【一般】平方公分綜合習題
# W4l0TIo0YQXLT/c8/Uy7OLtElmNuNWPODI7HkJ0NaI0=    【一般】周長與面積綜合習題
# gvez7GFXUbuQl27U5+p/4QwFZZyXP2QFYQdoor8ZkeE=     【一般】周長與面積的應用
# Name: content_pretty_name, dtype: object

# %% [markdown]
# - Cleaning Text

# %%
df_InfoContent['content_pretty_name'] = df_InfoContent['content_pretty_name'].replace(to_replace=r'\【.*\】', value='', regex=True)

# %%
df_InfoContent['content_pretty_name']
# Out:
# ucid
# odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=    怎樣解題：數量關係
# dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=       和差問題 1
# C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=       雞兔問題 1
# jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=       年齡問題 1
# M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=         追趕問題
#                                                   ...
# NPkrCjbLK35wefMCv6y6XMO5eYO/gthS6LGwrdjG2OQ=     平方公分綜合習題
# 3xqxJN2W+KEo3SBjh7HnXpGjB4ewSbm1j/18fCn05yc=    周長與面積綜合習題
# j4rGpwpqhLE9foelXD2yjokS0u3QR+ULhNqLGeF/4sk=     平方公分綜合習題
# W4l0TIo0YQXLT/c8/Uy7OLtElmNuNWPODI7HkJ0NaI0=    周長與面積綜合習題
# gvez7GFXUbuQl27U5+p/4QwFZZyXP2QFYQdoor8ZkeE=     周長與面積的應用
# Name: content_pretty_name, Length: 1330, dtype: object

# %% [markdown]
# - Translating Text

# %%
df_InfoContent['content_pretty_name'] = df_InfoContent['content_pretty_name'].apply(translator.translate, src='zh-tw', dest='en').apply(getattr, args=('text',))

# %%
#pd.get_option("display.max_rows")
#pd.set_option("display.max_rows", 1000)
df_InfoContent.tail(10)
# Out:
#                                                                          content_pretty_name  \
# ucid
# m/JWFlWTObOlrpPo0GSe5ZY8bBRPfH9U/ZsdbbyIa5w=                                       周長與面積綜合習題
# ZOO50WfENqtWGe4uBkJcqW4nppgtuJKCAoqx34z8eOw=       Perimeter formula of rectangle and square
# /fn8Ym16AvhuhgFRtoeZ4sRU9ZRhvvpYN90SUH7zQ4M=                                    長方形、正方形的面積公式
# +ZVl8HEbTM1GOoCTt2wxAfzQswvAWL3L8e5mLuyy1dY=                                       平方公尺與平方公分
# j8b2h08zIbWHp6sKBsI0qaQuiA3vUGMjaYZFFE/gQ3I=                                         複合圖形的面積
# NPkrCjbLK35wefMCv6y6XMO5eYO/gthS6LGwrdjG2OQ=  Comprehensive exercises for square centimeters
# 3xqxJN2W+KEo3SBjh7HnXpGjB4ewSbm1j/18fCn05yc=                                       周長與面積綜合習題
# j4rGpwpqhLE9foelXD2yjokS0u3QR+ULhNqLGeF/4sk=  Comprehensive exercises for square centimeters
# W4l0TIo0YQXLT/c8/Uy7OLtElmNuNWPODI7HkJ0NaI0=  Comprehensive exercises for perimeter and area
# gvez7GFXUbuQl27U5+p/4QwFZZyXP2QFYQdoor8ZkeE=                                        周長與面積的應用
#
#                                              content_kind difficulty subject  \
# ucid
# m/JWFlWTObOlrpPo0GSe5ZY8bBRPfH9U/ZsdbbyIa5w=     Exercise       easy    math
# ZOO50WfENqtWGe4uBkJcqW4nppgtuJKCAoqx34z8eOw=     Exercise       easy    math
# /fn8Ym16AvhuhgFRtoeZ4sRU9ZRhvvpYN90SUH7zQ4M=     Exercise       easy    math
# +ZVl8HEbTM1GOoCTt2wxAfzQswvAWL3L8e5mLuyy1dY=     Exercise       easy    math
# j8b2h08zIbWHp6sKBsI0qaQuiA3vUGMjaYZFFE/gQ3I=     Exercise       easy    math
# NPkrCjbLK35wefMCv6y6XMO5eYO/gthS6LGwrdjG2OQ=     Exercise       hard    math
# 3xqxJN2W+KEo3SBjh7HnXpGjB4ewSbm1j/18fCn05yc=     Exercise       hard    math
# j4rGpwpqhLE9foelXD2yjokS0u3QR+ULhNqLGeF/4sk=     Exercise     normal    math
# W4l0TIo0YQXLT/c8/Uy7OLtElmNuNWPODI7HkJ0NaI0=     Exercise     normal    math
# gvez7GFXUbuQl27U5+p/4QwFZZyXP2QFYQdoor8ZkeE=     Exercise     normal    math
#
#                                              learning_stage  \
# ucid
# m/JWFlWTObOlrpPo0GSe5ZY8bBRPfH9U/ZsdbbyIa5w=     elementary
# ZOO50WfENqtWGe4uBkJcqW4nppgtuJKCAoqx34z8eOw=     elementary
# /fn8Ym16AvhuhgFRtoeZ4sRU9ZRhvvpYN90SUH7zQ4M=     elementary
# +ZVl8HEbTM1GOoCTt2wxAfzQswvAWL3L8e5mLuyy1dY=     elementary
# j8b2h08zIbWHp6sKBsI0qaQuiA3vUGMjaYZFFE/gQ3I=     elementary
# NPkrCjbLK35wefMCv6y6XMO5eYO/gthS6LGwrdjG2OQ
# 3xqxJN2W+KEo3SBjh7HnXpGjB4ewSbm1j/18fCn05yc=  Ny1/uHUXA4pvWVN1nVWv+vsdaQde7StyoQV8HAyJD80=
# j4rGpwpqhLE9foelXD2yjokS0u3QR+ULhNqLGeF/4sk=  JtYpwXqNWwRqPrXYh0JhE2lEEUI1gKRPdDH3jYwhqMo=
# W4l0TIo0YQXLT/c8/Uy7OLtElmNuNWPODI7HkJ0NaI0=  Ny1/uHUXA4pvWVN1nVWv+vsdaQde7StyoQV8HAyJD80=
# gvez7GFXUbuQl27U5+p/4QwFZZyXP2QFYQdoor8ZkeE=  Ny1/uHUXA4pvWVN1nVWv+vsdaQde7StyoQV8HAyJD80=

# %% [markdown]
# ### Parsing Date

# %%
df_InfoUser['date_login'] = pd.to_datetime(df_InfoUser['first_login_date_TW'], format='%Y-%m-%d')
df_InfoUser['year_login'] = df_InfoUser['date_login'].apply(lambda x: x.year)
df_InfoUser['month_login'] = df_InfoUser['date_login'].apply(lambda x: x.month)
df_InfoUser['day_login'] = df_InfoUser['date_login'].apply(lambda x: x.day)

# %%
df_LogProblem['datetime_attempt'] = pd.to_datetime(df_LogProblem['timestamp_TW'], format='%Y-%m-%d %H:%M:%S %Z')
df_LogProblem['year_attempt'] = df_LogProblem['datetime_attempt'].apply(lambda x: x.year)
df_LogProblem['month_attempt'] = df_LogProblem['datetime_attempt'].apply(lambda x: x.month)
df_LogProblem['day_attempt'] = df_LogProblem['datetime_attempt'].apply(lambda x: x.day)

# %%
df_LogProblem.head()
# Out:
#                  timestamp_TW                                          uuid  \
# 6814  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 6815  2018-09-28 10:15:00 UTC  0+VU/Zb0Q96uoByuRhl7r9bJuJO6CKWpsmNMEuijSzc=
# 6816  2018-09-05 20:00:00 UTC  g8DnYvIqpolw10XlwWeIWv6NbDPByUbmgH8EshJqBns=
# 6817  2018-09-14 16:30:00 UTC  kSyUTFlepsYUD723IPL/jEZ520xaKbscrBmNtBUFR1o=
# 6818  2018-09-13 16:00:00 UTC  XMFbFA7C49+LRhUddhelfPpA6F5dbOoxeyL3eYbuTlY=
#
#                                               ucid  \
# 6814  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 6815  /d39FzqaM3PZzpoMXxA80PMICsVhzfL6MGSCqZtsQOo=
# 6816  YuGOmB+frbM8rfAa0RJE882R+IoMf9N89OiVqLbAHBw=
# 6817  BG1RsWojzEHzV28RBm/1iKi1NyZgDcDomLYEJSV6lmo=
# 6818  qPHR8aBqOhKij9IS/Y8IR8prwWruoDBGU1tVUhXDJkE=
#
#                                               upid  problem_number  \
# 6814  ZmKEZ0F2WFqhlL7KFfJcHEnZCZu0e4p+CVG5rSlyKYk=               2
# 6815  tO9dyvadKWMVQgEx/BXtRIYJ2TRJFQgwvcsBwFb4+xI=               6
# 6816  6Lxz6aXvgyw3vZd3v8g6jgoCRDPOQzVPx/dnEC0o7DQ=               4
# 6817  1fIjdakTApQp5PfWog87uOmM6JuoNE/oQq2y5/fMmfw=               3
# 6818  8V/NT6M+er2I3V3ZIWRNo4Qbo3Iad89PHbeeZeoZeF0=              12
#
#       exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 6814                                1        True               11
# 6815                                1        True               26
# 6816                                1        True               78
# 6817                                1        True                7
# 6818                                1        True               48
#
#       total_attempt_cnt  used_hint_cnt  is_hint_used is_downgrade is_upgrade  \
# 6814                  1              0         False          NaN        NaN
# 6815                  1              0         False          NaN        NaN
# 6816                  1              0         False          NaN        NaN
# 6817                  1              0         False          NaN        NaN
# 6818                  1              0         False        False       True
#
#       level          datetime_attempt  year_attempt  month_attempt  \
# 6814      0 2018-09-28 20:00:00+00:00          2018              9
# 6815      0 2018-09-28 10:15:00+00:00          2018              9
# 6816      0 2018-09-05 20:00:00+00:00          2018              9
# 6817      0 2018-09-14 16:30:00+00:00          2018              9
# 6818      1 2018-09-13 16:00:00+00:00          2018              9
#
#       day_attempt
# 6814           28
# 6815           28
# 6816            5
# 6817           14
# 6818           13

# %% [markdown]
# ## Exploratory Data Analysis
#
# Here we perform exploratory statistical analysis and make some plots to visualise the interesting aspects of our dataset.

# %% [markdown]
# ### Time period of dataset
#
# The first thing we establish here is the timeframe of our dataset: from 5th January 2015 to 31st March 2016, spanning 451 days.

# %%
print ("The first chronological datapoint occurred on:")
print (df_LogProblem.loc[df_LogProblem['datetime_attempt'].idxmin(),'datetime_attempt'])
print ("The last chronological datapoints occurred on:")
print (df_LogProblem.loc[df_LogProblem['datetime_attempt'].idxmax(),'datetime_attempt'])
print ("Spanning over a period of:")
print (df_LogProblem.loc[df_LogProblem['datetime_attempt'].idxmax(),'datetime_attempt'] - df_LogProblem.loc[df_LogProblem['datetime_attempt'].idxmin(),'datetime_attempt'])
# Out:
# The first chronological datapoint occurred on:
# 2018-08-01 07:45:00+00:00
# The last chronological datapoints occurred on:
# 2018-12-31 23:45:00+00:00
# Spanning over a period of:
# 152 days 16:00:00

# %%
df.groupby(df['date'].dt.strftime('%B'))['Revenue'].sum().sort_values()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-223-cbd549f02e17> in <module>
# ----> 1 dates = plt.dates.date2num(df_LogProblem['datetime_attempt'])
#       2 matplotlib.pyplot.plot_date(dates, values)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'dates'

# %% [markdown]
# ### Merge Dataset

# %%
merge_df_LogProblem_InfoUser = pd.merge(df_LogProblem, df_InfoUser, on = 'uuid')
merge_df_LogProblem_InfoUser.head()
# Out:
#               timestamp_TW                                          uuid  \
# 0  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 1  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 2  2018-10-24 10:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 3  2018-10-31 19:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 4  2018-10-19 14:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
#
#                                            ucid  \
# 0  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 1  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 2  RKkxBe+3Z33I75tZfZ8EY7LtVnN5QEfE8O0y6bPFCeo=
# 3  MUbqU/Il0Jtq/WAby1VtcO+pS/tc7QnNE3TI/GuzuMM=
# 4  Qx6mwirYKln7CTvOXad5Do5OkVKmypYSQfFs0MB6Cvs=
#
#                                            upid  problem_number  \
# 0  ZmKEZ0F2WFqhlL7KFfJcHEnZCZu0e4p+CVG5rSlyKYk=               2
# 1  Ilkv6d+nFM00DAFC0cnj++DQvBFu6eMcD7UCIGCNrws=              19
# 2  STZD5cyjUf3J2AETFRoMb+LREPAPoAY3Cc8b63jV3Qw=              19
# 3  JrljyCVNZ6U5o5pyaJ/SZGoSW9QoWVGk2kOHeNFJk8A=               5
# 4  3etEMUOdg1aQ094NPnamWU0T0NbViDtKHt8ytLDsp2k=               3
#
#    exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                1        True               11
# 1                                2        True               19
# 2                                2       False               18
# 3                                1       False              112
# 4                                1       False              123
#
#    total_attempt_cnt  used_hint_cnt  ...  belongs_to_class_cnt has_class_cnt  \
# 0                  1              0  ...                    10             1
# 1                  1              0  ...                    10             1
# 2                  3              4  ...                    10             1
# 3                  4              3  ...                    10             1
# 4                 11              3  ...                    10             1
#
#     datetime  year month  day  date_login  year_login month_login  day_login
# 0 2018-09-05  2018     9    5  2018-09-05        2018           9          5
# 1 2018-09-05  2018     9    5  2018-09-05        2018           9          5
# 2 2018-09-05  2018     9    5  2018-09-05        2018           9          5
# 3 2018-09-05  2018     9    5  2018-09-05        2018           9          5
# 4 2018-09-05  2018     9    5  2018-09-05        2018           9          5
#
# [5 rows x 37 columns]

# %%
merge_df_LogProblem_InfoUser_InfoContent = pd.merge(merge_df_LogProblem_InfoUser, df_InfoContent, on = 'ucid')

# %%
merge_df_LogProblem_InfoUser_InfoContent.head(50)
# Out:
#                timestamp_TW                                          uuid  \
# 0   2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 1   2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 2   2018-09-30 17:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 3   2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 4   2018-09-30 16:45:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 5   2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 6   2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 7   2018-10-01 06:30:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 8   2018-09-30 17:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 9   2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 10  2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 11  2018-09-30 16:45:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 12  2018-09-30 17:30:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 13  2018-09-30 17:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 14  2018-09-30 16:45:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 15  2018-09-30 17:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 16  2018-09-30 17:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 17  2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 18  2018-09-30 16:45:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 19  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 20  2018-09-30 17:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 21  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 22  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 23  2018-09-30 17:30:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 24  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 25  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 26  2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 27  2018-09-30 17:30:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 28  2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 29  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 30  2018-09-30 17:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 31  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 32  2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 33  2018-09-30 17:30:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 34  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 35  2018-10-01 06:30:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 36  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 37  2018-10-01 06:30:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 38  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 39  2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 40  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 41  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 42  2018-09-30 16:45:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 43  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 44  2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 45  2018-09-28 20:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 46  2018-09-30 17:30:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 47  2018-09-30 17:30:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 48  2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 49  2018-09-30 17:15:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
#
#                                             ucid  \
# 0   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 1   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 2   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 3   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 4   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 5   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 6   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 7   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 8   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 9   Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 10  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 11  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 12  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 13  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 14  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 15  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 16  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 17  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 18  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 19  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 20  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 21  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 22  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 23  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 24  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 25  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 26  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 27  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 28  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 29  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 30  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 31  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 32  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 33  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 34  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 35  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 36  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 37  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 38  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 39  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 40  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 41  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 42  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 43  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 44  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 45  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 46  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 47  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 48  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 49  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
#
#                                             upid  problem_number  \
# 0   ZmKEZ0F2WFqhlL7KFfJcHEnZCZu0e4p+CVG5rSlyKYk=               2
# 1   Ilkv6d+nFM00DAFC0cnj++DQvBFu6eMcD7UCIGCNrws=              19
# 2   owavtXN1kkSf8ts9s7/RdlZ0URghFjbbDdYSbeTdGDI=              39
# 3   fXsDzZlk7znVxvd/mZ9sEVdhUtqnLMJTj+PyOzaeLLk=              17
# 34  OqFse34H4NRXOiioHM3PzzAoZHTsgeCdZHJnJjeyDJg=              16
# 35  vIKhVaa+X6z2FkWpnlenIX1nNbPqQq2Ququ87x0EZZw=              67
# 36  WxmXxrzF0FeD1obGNQ5TaIG1wIJ2ZQU1LcjN2u3eKB4=               9
# 37  ee3qp7lqL7naUFma1iKFBz8lkPAi2ZjaL//B/6cLuf0=              70
# 38  owavtXN1kkSf8ts9s7/RdlZ0URghFjbbDdYSbeTdGDI=               6
# 39  Ilkv6d+nFM00DAFC0cnj++DQvBFu6eMcD7UCIGCNrws=              44
# 40  gqCP32vX1ttqyji0IJnH1swnhjSpehX4ebHKh4Q/Isk=              11
# 41  kVKYhyvsGHV5RG7YfDEIGLgoTETpX3sU0ep8Nr/njFQ=               4
# 42  fXsDzZlk7znVxvd/mZ9sEVdhUtqnLMJTj+PyOzaeLLk=              34
# 43  nlsHIUQoWL0vQurqOn6PGP1n2yNB3fSKYAJbd7WDLyw=              10
# 44  OqFse34H4NRXOiioHM3PzzAoZHTsgeCdZHJnJjeyDJg=              50
# 45  vIKhVaa+X6z2FkWpnlenIX1nNbPqQq2Ququ87x0EZZw=              12
# 46  ZmKEZ0F2WFqhlL7KFfJcHEnZCZu0e4p+CVG5rSlyKYk=              61
# 47  lLKjGb3st62tBUDsxvR/9Dg+FDFDFtyq8E5Qd/SWZI0=              64
# 48  dJkuZnbawiqvxWE5ecFmFRkPfG0fHiyet+MEeFSGgtM=              57
# 49  fXsDzZlk7znVxvd/mZ9sEVdhUtqnLMJTj+PyOzaeLLk=              54
#
#     exercise_problem_repeat_session  is_correct  total_sec_taken  \
# 0                                 1        True               11
# 1                                 2        True               19
# 2                                 3       False               81
# 3                                 2       False               16
# 4                                 3        True               11
# 5                                 2        True               23
# 6                                 3        True               12
# 7                                 5       False               41
# 8                                 3        True                9
# 9                                 1        True               63
# 10                                4        True               93
# 11                                3        True               27
# 12                                4       False                7
# 13                                3        True               92
# 14                                3        True               11
# 15                                3        True               98
# 16                                3        True               21
# 17                                4        True                9
# 18                                2        True               16
# 19                                2       False               12
# 20                                3        True               80
# 21                                1        True               25
# 22                                1       False               31
# 23                                4        True                7
# 24                                1       False                8
# 25                                1        True               22
# 26                                3        True               43
# 27                                5        True                8
# 28                                3        True               16
# 29                                2       False               12
# 30                                2        True               93
# 31                                1       False               20
# 32                                4        True               55
# 33                                5       False               12
# 34                                1        True               18
# 35                                5        True               78
# 36                                1       False                6
# 37                                5        True               10
# 38                                1       False               16
# 39                                4        True                8
# 40                                1        True               11
# 41                                1       False               25
# 42                                3        True               69
# 43                                1       False               15
# 44                                3        True               13
# 45                                1       False               12
# 46                                5        True                8
# 47                                4        True                9
# 48                                3       False              113
# 49                                4        True               11
#
#     total_attempt_cnt  used_hint_cnt  ...  day_login content_pretty_name  \
# 0                   1              0  ...          5               倍數的應用
# 1                   1              0  ...          5               倍數的應用
# 2                   2              3  ...          5               倍數的應用
# 3                   3              3  ...          5               倍數的應用
# 4                   1              0  ...          5               倍數的應用
# 5                   1              0  ...          5               倍數的應用
# 6                   1              0  ...          5               倍數的應用
# 7                   2              3  ...          5               倍數的應用
# 8                   1              0  ...          5               倍數的應用
# 9                   1              0  ...          5               倍數的應用
# 10                  1              0  ...          5               倍數的應用
# 11                  1              0  ...          5               倍數的應用
# 12                  1              3  ...          5               倍數的應用
# 13                  1              0  ...          5               倍數的應用
# 14                  1              0  ...          5               倍數的應用
# 15                  1              0  ...          5               倍數的應用
# 16                  1              0  ...          5               倍數的應用
# 17                  1              0  ...          5               倍數的應用
# 18                  1              0  ...          5               倍數的應用
# 19                  1              3  ...          5               倍數的應用
# 20                  1              0  ...          5               倍數的應用
# 21                  1              0  ...          5               倍數的應用
# 22                  5              3  ...          5               倍數的應用
# 23                  1              0  ...          5               倍數的應用
# 24                  1              3  ...          5               倍數的應用
# 25                  1              0  ...          5               倍數的應用
# 26                  1              0  ...          5               倍數的應用
# 27                  1              0  ...          5               倍數的應用
# 28                  1              0  ...          5               倍數的應用
# 29                  3              2  ...          5               倍數的應用
# 30                  1              0  ...          5               倍數的應用
# 31                  1              3  ...          5               倍數的應用
# 32                  1              0  ...          5               倍數的應用
# 33                  1              3  ...          5               倍數的應用
# 34                  1              0  ...          5               倍數的應用
# 35                  1              0  ...          5               倍數的應用
# 36                  1              3  ...          5               倍數的應用
# 37                  1              0  ...          5               倍數的應用
# 38                  1              3  ...          5               倍數的應用
# 39                  1              0  ...          5               倍數的應用
# 40                  1              0  ...          5               倍數的應用
# 41                  1              3  ...          5               倍數的應用
# 42                  1              0  ...          5               倍數的應用
# 43                  3              2  ...          5               倍數的應用
# 44                  1              0  ...          5               倍數的應用
# 45                  1              3  ...          5               倍數的應用
# 46                  1              0  ...          5               倍數的應用
# 47                  1              0  ...          5               倍數的應用
# 48                  1              1  ...          5               倍數的應用
# 49                  1              0  ...          5               倍數的應用
#
#    content_kind  difficulty subject  learning_stage  \
# 0      Exercise        easy    math      elementary
# 1      Exercise        easy    math      elementary
# 2      Exercise        easy    math      elementary
# 3      Exercise        easy    math      elementary
# 4      Exercise        easy    math      elementary
# 5      Exercise        easy    math      elementary
# 6      Exercise        easy    math      elementary
# 7      Exercise        easy    math      elementary
# 8      Exercise        easy    math      elementary
# 9      Exercise        easy    math      elementary
# 10     Exercise        easy    math      elementary
# 11     Exercise        easy    math      elementary
# 12     Exercise        easy    math      elementary
# 13     Exercise        easy    math      elementary
# 14     Exercise        easy    math      elementary
# 15     Exercise        easy    math      elementary
# 16     Exercise        easy    math      elementary
# 17     Exercise        easy    math      elementary
# 18     Exercise        easy    math      elementary
# 19     Exercise        easy    math      elementary
# 20     Exercise        easy    math      elementary
# 21     Exercise        easy    math      elementary
# 22     Exercise        easy    math      elementary
# 23     Exercise        easy    math      elementary
# 24     Exercise        easy    math      elementary
# 25     Exercise        easy    math      elementary
# 26     Exercise        easy    math      elementary
# 27     Exercise        easy    math      elementary
# 28     Exercise        easy    math      elementary
# 29     Exercise        easy    math      elementary
# 30     Exercise        easy    math      elementary
# 31     Exercise        easy    math      elementary
# 32     Exercise        easy    math      elementary
# 33     Exercise        easy    math      elementary
# 34     Exercise        easy    math      elementary
# 35     Exercise        easy    math      elementary
# 36     Exercise        easy    math      elementary
# 37     Exercise        easy    math      elementary
# 38     Exercise        easy    math      elementary
# 39     Exercise        easy    math      elementary
# 40     Exercise        easy    math      elementary
# 41     Exercise        easy    math      elementary
# 42     Exercise        easy    math      elementary
# 43     Exercise        easy    math      elementary
# 44     Exercise        easy    math      elementary
# 45     Exercise        easy    math      elementary
# 46     Exercise        easy    math      elementary
# 47     Exercise        easy    math      elementary
# 48     Exercise        easy    math      elementary
# 49     Exercise        easy    math      elementary
#
#                                        level1_id  \
# 0   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 1   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 2   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 3   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 4   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 5   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 6   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 7   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 8   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 9   aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 10  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 11  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 12  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 13  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 14  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 15  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 16  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 17  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 18  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 19  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 20  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 21  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 22  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 23  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 24  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 25  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 26  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 27  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 28  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 29  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 30  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 31  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 32  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 33  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 34  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 35  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 36  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 37  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 38  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 39  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 40  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 41  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 42  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 43  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 44  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 45  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 46  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 47  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 48  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 49  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
#
#                                        level2_id  \
# 0   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 1   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 2   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 3   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 4   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 5   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 6   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 7   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 8   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 9   7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 10  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 11  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 12  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 13  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 14  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 15  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 16  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 17  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 18  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 19  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 20  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 21  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 22  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 23  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 24  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 25  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 26  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 27  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 28  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 29  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 30  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 31  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 32  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 33  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 34  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 35  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 36  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 37  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 38  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 39  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 40  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 41  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 42  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 43  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 44  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 45  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 46  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 47  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 48  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
# 49  7f73q332BKPBXaixasa4EkUb+pF6VAsLxNIg4506JJs=
#
#                                        level3_id  \
# 0   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 1   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 2   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 3   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 4   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 5   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 6   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 7   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 8   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 9   ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 10  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 11  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 12  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 13  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 14  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 15  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 16  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 17  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 18  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 19  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 20  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 21  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 22  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 23  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 24  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 25  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 26  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 27  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 28  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 29  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 30  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 31  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 32  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 33  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 34  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 35  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 36  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 37  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 38  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 39  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 40  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 41  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 42  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 43  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 44  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 45  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 46  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 47  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 48  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
# 49  ItasYR+er/FlZlRvL66/NB3wY0AvmlrZKoqe4gmPyD0=
#
#                                        level4_id
# 0   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 1   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 2   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 3   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 4   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 5   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 6   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 7   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 8   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 9   VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 10  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 11  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 12  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 13  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 14  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 15  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 16  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 17  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 18  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 19  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 20  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 21  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 22  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 23  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 24  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 25  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 26  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 27  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 28  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 29  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 30  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 31  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 32  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 33  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 34  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 35  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 36  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 37  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 38  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 39  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 40  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 41  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 42  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 43  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 44  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 45  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 46  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 47  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 48  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
# 49  VHYt8IeoqiIPVsB+32JAhIjK9jU+pnr11fL80QshARI=
#
# [50 rows x 46 columns]

# %%
merge_df_LogProblem_InfoUser_InfoContent.groupby('content_pretty_name').groups
# Out:
# {'A brief note on algebraic expressions': Int64Index([2018314, 2018315, 2018316, 2018317, 2018318, 2018319, 2018320,
#              2018321, 2018322, 2018323,
#              ...
#              2035583, 2035584, 2035585, 2035586, 2035587, 2035588, 2035589,
#              2035590, 2035591, 2035592],
#             dtype='int64', length=17279),
#  'A quadratic equation with a large constant term': Int64Index([6631840, 6631841, 6631842, 6631843, 6631844, 6631845, 6631846,
#              6631847, 6631848, 6631849,
#              ...
#              6634240, 6634241, 6634242, 6634243, 6634244, 6634245, 6634246,
#              6634247, 6634248, 6634249],
#             dtype='int64', length=2410),
#  'Add and subtract two decimal places on the number line': Int64Index([4131448, 4131449, 4131450, 4131451, 4131452, 4131453, 4131454,
#              4131455, 4131456, 4131457,
#              ...
#              4134417, 4134418, 4134419, 4134420, 4134421, 4134422, 4134423,
#              4134424, 4134425, 4134426],
#             dtype='int64', length=2979),
#  'Adding centimeters and millimeters': Int64Index([5630176, 5630177, 5630178, 5630179, 5630180, 5630181, 5630182,
#              5630183, 5630184, 5630185,
#              ...
#              5635159, 5635160, 5635161, 5635162, 5635163, 5635164, 5635165,
#              5635166, 5635167, 5635168],
#             dtype='int64', length=4993),
#  'Adding one decimal place 2': Int64Index([5943922, 5943923, 5943924, 5943925, 5943926, 5943927, 5943928,
#              5943929, 5943930, 5943931,
#              ...
#              5946501, 5946502, 5946503, 5946504, 5946505, 5946506, 5946507,
#              5946508, 5946509, 5946510],
#             dtype='int64', length=2589),
#  'Adding two decimal places': Int64Index([5517367, 5517368, 5517369, 5517370, 5517371, 5517372, 5517373,
#              5517374, 5517375, 5517376,
#              ...
#              5523957, 5523958, 5523959, 5523960, 5523961, 5523962, 5523963,
#              5523964, 5523965, 5523966],
#             dtype='int64', length=6600),
#  'Addition and subtraction combined formula: Calculate from left to right': Int64Index([6832776, 6832777, 6832778, 6832779, 6832780, 6832781, 6832782,
#              6832783, 6832784, 6832785,
#              ...
#              6835664, 6835665, 6835666, 6835667, 6835668, 6835669, 6835670,
#              6835671, 6835672, 6835673],
#             dtype='int64', length=2898),
#  'Addition and subtraction combined: those with parentheses are calculated first': Int64Index([2952643, 2952644, 2952645, 2952646, 2952647, 2952648, 2952649,
#              2952650, 2952651, 2952652,
#              ...
#              2955923, 2955924, 2955925, 2955926, 2955927, 2955928, 2955929,
#              2955930, 2955931, 2955932],
#             dtype='int64', length=3290),
#  'Addition and subtraction estimation of decimals': Int64Index([4526756, 4526757, 4526758, 4526759, 4526760, 4526761, 4526762,
#              4526763, 4526764, 4526765,
#              ...
#              4528089, 4528090, 4528091, 4528092, 4528093, 4528094, 4528095,
#              4528096, 4528097, 4528098],
#             dtype='int64', length=1343),
#  'Addition and subtraction mixed calculation of fractions: Addition and subtraction mixed': Int64Index([6755012, 6755013, 6755014, 6755015, 6755016, 6755017, 6755018,
#              6755019, 6755020, 6755021,
#              ...
#              6755123, 6755124, 6755125, 6755126, 6755127, 6755128, 6755129,
#              6755130, 6755131, 6755132],
#             dtype='int64', length=121),
#  'Addition and subtraction mixed calculation of fractions: consecutive subtraction of two numbers': Int64Index([6758907, 6758908, 6758909, 6758910, 6758911, 6758912, 6758913,
#              6758914, 6758915, 6758916, 6758917, 6758918, 6758919, 6758920,
#              6758921, 6758922, 6758923, 6758924, 6758925, 6758926, 6758927,
#  'Angle bisector properties': Int64Index([7175163, 7175164, 7175165, 7175166, 7175167, 7175168, 7175169,
#              7175170, 7175171, 7175172,
#              ...
#              7175321, 7175322, 7175323, 7175324, 7175325, 7175326, 7175327,
#              7175328, 7175329, 7175330],
#             dtype='int64', length=168),
#  'Angle comprehensive exercises': Int64Index([1574952, 1574953, 1574954, 1574955, 1574956, 1574957, 1574958,
#              1574959, 1574960, 1574961,
#              ...
#              1589015, 1589016, 1589017, 1589018, 1589019, 1589020, 1589021,
#              1589022, 1589023, 1589024],
#             dtype='int64', length=14073),
#  'Application of Discriminant': Int64Index([6464788, 6464789, 6464790, 6464791, 6464792, 6464793, 6464794,
#              6464795, 6464796, 6464797,
#              ...
#              6467093, 6467094, 6467095, 6467096, 6467097, 6467098, 6467099,
#              6467100, 6467101, 6467102],
#             dtype='int64', length=2315),
#  'Application of Quadratic Function Graphics-Will be removed soon': Int64Index([7195884, 7195885, 7195886, 7195887, 7195888, 7195889, 7195890,
#              7195891, 7195892, 7195893,
#              ...
#              7196051, 7196052, 7196053, 7196054, 7196055, 7196056, 7196057,
#              7196058, 7196059, 7196060],
#             dtype='int64', length=177),
#  'Application of Triangle Center of Gravity': Int64Index([7064738, 7064739, 7064740, 7064741, 7064742, 7064743, 7064744,
#              7064745, 7064746, 7064747,
#              ...
#              7065257, 7065258, 7065259, 7065260, 7065261, 7065262, 7065263,
#              7065264, 7065265, 7065266],
#             dtype='int64', length=529),
#  'Application of addition and subtraction of fractions with different denominators': Int64Index([681764, 681765, 681766, 681767, 681768, 681769, 681770, 681771,
#              681772, 681773,
#              ...
#              689460, 689461, 689462, 689463, 689464, 689465, 689466, 689467,
#              689468, 689469],
#             dtype='int64', length=7706),
#  'Application of addition and subtraction of one decimal place': Int64Index([5310978, 5310979, 5310980, 5310981, 5310982, 5310983, 5310984,
#              5310985, 5310986, 5310987,
#              ...
#              5313805, 5313806, 5313807, 5313808, 5313809, 5313810, 5313811,
#              5313812, 5313813, 5313814],
#             dtype='int64', length=2837),
#  'Application of addition and subtraction of scores': Int64Index([5830579, 5830580, 5830581, 5830582, 5830583, 5830584, 5830585,
#              5830586, 5830587, 5830588,
#              ...
#              5833071, 5833072, 5833073, 5833074, 5833075, 5833076, 5833077,
#              5833078, 5833079, 5833080],
#             dtype='int64', length=2502),
#  'Application of addition and subtraction of two decimal places': Int64Index([2907829, 2907830, 2907831, 2907832, 2907833, 2907834, 2907835,
#              2907836, 2907837, 2907838,
#              ...
#              2912984, 2912985, 2912986, 2912987, 2912988, 2912989, 2912990,
#              2912991, 2912992, 2912993],
#             dtype='int64', length=5165),
#  'Application of capacity': Int64Index([5946511, 5946512, 5946513, 5946514, 5946515, 5946516, 5946517,
#              5946518, 5946519, 5946520,
#              ...
#              5955511, 5955512, 5955513, 5955514, 5955515, 5955516, 5955517,
#              5955518, 5955519, 5955520],
#             dtype='int64', length=9010),
#  'Application of common factors': Int64Index([409994, 409995, 409996, 409997, 409998, 409999, 410000, 410001,
#              410002, 410003,
#              3582708, 3582709, 3582710, 3582711, 3582712, 3582713, 3582714,
#              3582715, 3582716, 3582717],
#             dtype='int64', length=3396),
#  'Application of the greatest common factor': Int64Index([4628606, 4628607, 4628608, 4628609, 4628610, 4628611, 4628612,
#              4628613, 4628614, 4628615,
#              ...
#              4638646, 4638647, 4638648, 4638649, 4638650, 4638651, 4638652,
#              4638653, 4638654, 4638655],
#             dtype='int64', length=10050),
#  'Application of the interchange of fractions and decimals': Int64Index([6368876, 6368877, 6368878, 6368879, 6368880, 6368881, 6368882,
#              6368883, 6368884, 6368885,
#              ...
#              6370864, 6370865, 6370866, 6370867, 6370868, 6370869, 6370870,
#              6370871, 6370872, 6370873],
#             dtype='int64', length=1998),
#  'Application of the nature of parallel line section': Int64Index([6985705, 6985706, 6985707, 6985708, 6985709, 6985710, 6985711,
#              6985712, 6985713, 6985714,
#              ...
#              6986960, 6986961, 6986962, 6986963, 6986964, 6986965, 6986966,
#              6986967, 6986968, 6986969],
#             dtype='int64', length=1265),
#  'Application of the sum of the internal angles of a polygon': Int64Index([3142681, 3142682, 3142683, 3142684, 3142685, 3142686, 3142687,
#              3142688, 3142689, 3142690,
#              ...
#              3154668, 3154669, 3154670, 3154671, 3154672, 3154673, 3154674,
#              3154675, 3154676, 3154677],
#             dtype='int64', length=11997),
#  'Application of three formulas for rate': Int64Index([4474835, 4474836, 4474837, 4474838, 4474839, 4474840, 4474841,
#              4474842, 4474843, 4474844,
#              ...
#              4479756, 4479757, 4479758, 4479759, 4479760, 4479761, 4479762,
#              4479763, 4479764, 4479765],
#             dtype='int64', length=4931),
#  'Application of triangular area 1': Int64Index([602376, 602377, 602378, 602379, 602380, 602381, 602382, 602383,
#              602384, 602385,
#              ...
#              625422, 625423, 625424, 625425, 625426, 625427, 625428, 625429,
#              625430, 625431],
#             dtype='int64', length=23056),
#  'Application of weight': Int64Index([3082329, 3082330, 3082331, 3082332, 3082333, 3082334, 3082335,
#              3082336, 3082337, 3082338,
#              ...
#              3092198, 3092199, 3092200, 3092201, 3092202, 3092203, 3092204,
#              3092205, 3092206, 3092207],
#             dtype='int64', length=9879),
#  'Area and square centimeters': Int64Index([5247846, 5247847, 5247848, 5247849, 5247850, 5247851, 5247852,
#              5247853, 5247854, 5247855,
#              ...
#              5252406, 5252407, 5252408, 5252409, 5252410, 5252411, 5252412,
#              5252413, 5252414, 5252415],
#             dtype='int64', length=4570),
#  'Area of \u200b\u200bcomposite figure': Int64Index([2613987, 2613988, 2613989, 2613990, 2613991, 2613992, 2613993,
#              2613994, 2613995, 2613996,
#              ...
#              2617767, 2617768, 2617769, 2617770, 2617771, 2617772, 2617773,
#              2617774, 2617775, 2617776],
#             dtype='int64', length=3790),
#  'Arrangement of increasing power of polynomial': Int64Index([6566909, 6566910, 6566911, 6566912, 6566913, 6566914, 6566915,
#              6566916, 6566917, 6566918,
#              ...
#              6571936, 6571937, 6571938, 6571939, 6571940, 6571941, 6571942,
#              6571943, 6571944, 6571945],
#             dtype='int64', length=5037),
#  'Average concentration problem': Int64Index([7182709, 7182710, 7182711, 7182712, 7182713, 7182714, 7182715,
#              7182716, 7182717, 7182718, 7182719, 7182720, 7182721, 7182722,
#              7182723, 7182724, 7182725, 7182726, 7182727, 7182728, 7182729,
#              7182730, 7182731, 7182732, 7182733, 7182734, 7182735, 7182736,
#              7182737, 7182738, 7182739, 7182740, 7182741, 7182742, 7182743,
#              7182744, 7182745],
#             dtype='int64'),
#  'Basic concepts of plane Cartesian coordinates': Int64Index([7143023, 7143024, 7143025, 7143026, 7143027, 7143028, 7143029,
#              7143030, 7143031, 7143032,
#              ...
#              7143759, 7143760, 7143761, 7143762, 7143763, 7143764, 7143765,
#              7143766, 7143767, 7143768],
#             dtype='int64', length=746),
#  'Benchmark and comparison': Int64Index([5364819, 5364820, 5364821, 5364822, 5364823, 5364824, 5364825,
#              5364826, 5364827, 5364828,
#              ...
#              5669430, 5669431, 5669432, 5669433, 5669434, 5669435, 5669436,
#              5669437, 5669438, 5669439],
#             dtype='int64', length=482),
#  'Binary linear expression': Int64Index([7176855, 7176856, 7176857, 7176858, 7176859, 7176860, 7176861,
#              7176862, 7176863, 7176864,
#              ...
#              7177010, 7177011, 7177012, 7177013, 7177014, 7177015, 7177016,
#              7177017, 7177018, 7177019],
#             dtype='int64', length=165),
#  'Binary linear simultaneous equations': Int64Index([7081279, 7081280, 7081281, 7081282, 7081283, 7081284, 7081285,
#              7081286, 7081287, 7081288,
#              ...
#              7180094, 7180095, 7180096, 7180097, 7180098, 7180099, 7180100,
#              7180101, 7180102, 7180103],
#             dtype='int64', length=695),
#  'Binary linear simultaneous program': Int64Index([7092673, 7092674, 7092675, 7092676, 7092677, 7092678, 7092679,
#              7092680, 7092681, 7092682,
#              ...
#              7093182, 7093183, 7093184, 7093185, 7093186, 7093187, 7093188,
#              7093189, 7093190, 7093191],
#             dtype='int64', length=519),
#  'Binary linear substitution evaluation': Int64Index([7183016, 7183017, 7183018, 7183019, 7183020, 7183021, 7183022,
#              7183023, 7183024, 7183025,
#              ...
#              7183230, 7183231, 7183232, 7183233, 7183234, 7183235, 7183236,
#              7183237, 7183238, 7183239],
#             dtype='int64', length=224),
#  'Calculate the quantity by percentage': Int64Index([5771006, 5771007, 5771008, 5771009, 5771010, 5771011, 5771012,
#              5771013, 5771014, 5771015,
#              ...
#              5771371, 5771372, 5771373, 5771374, 5771375, 5771376, 5771377,
#              5771378, 5771379, 5771380],
#             dtype='int64', length=375),
#  'Calculate the quantity using the ratio': Int64Index([5896710, 5896711, 5896712, 5896713, 5896714, 5896715, 5896716,
#              5896717, 5896718, 5896719,
#              ...
#              5897706, 5897707, 5897708, 5897709, 5897710, 5897711, 5897712,
#              5897713, 5897714, 5897715],
#             dtype='int64', length=1006),
#  'Calculation exercises using the distribution law': Int64Index([637277, 637278, 637279, 637280, 637281, 637282, 637283, 637284,
#              637285, 637286,
#              ...
#              647026, 647027, 647028, 647029, 647030, 647031, 647032, 647033,
#              647034, 647035],
#             dtype='int64', length=9759),
#  'Calculation of addition and subtraction of kilometers and meters': Int64Index([3292519, 3292520, 3292521, 3292522, 3292523, 3292524, 3292525,
#              3292526, 3292527, 3292528,
#              ...
#              3295066, 3295067, 3295068, 3295069, 3295070, 3295071, 3295072,
#              3295073, 3295074, 3295075],
#             dtype='int64', length=2557),
#  'Calculation of addition and subtraction of liters and milliliters': Int64Index([6897736, 6897737, 6897738, 6897739, 6897740, 6897741, 6897742,
#              6897743, 6897744, 6897745,
#              ...
#              6901269, 6901270, 6901271, 6901272, 6901273, 6901274, 6901275,
#              6901276, 6901277, 6901278],
#             dtype='int64', length=3543),
#  'Calculation of addition and subtraction of time': Int64Index([5234849, 5234850, 5234851, 5234852, 5234853, 5234854, 5234855,
#              5234856, 5234857, 5234858,
#              ...
#              5237013, 5237014, 5237015, 5237016, 5237017, 5237018, 5237019,
#              5237020, 5237021, 5237022],
#             dtype='int64', length=2174),
#  'Calculation of discount': Int64Index([5580951, 5580952, 5580953, 5580954, 5580955, 5580956, 5580957,
#              5580958, 5580959, 5580960,
#              ...
#              5581326, 5581327, 5581328, 5581329, 5581330, 5581331, 5581332,
#              5581333, 5581334, 5581335],
#             dtype='int64', length=385),
#  'Calculation of function value': Int64Index([7197068, 7197069, 7197070, 7197071, 7197072, 7197073, 7197074,
#              7197075, 7197076, 7197077,
#              ...
#              7197160, 7197161, 7197162, 7197163, 7197164, 7197165, 7197166,
#              7197167, 7197168, 7197169],
#             dtype='int64', length=102),
#  'Calculation of integer multiples of fractions': Int64Index([1522167, 1522168, 1522169, 1522170, 1522171, 1522172, 1522173,
#              1522174, 1522175, 1522176,
#              ...
#              1526238, 1526239, 1526240, 1526241, 1526242, 1526243, 1526244,
#              1526245, 1526246, 1526247],
#             dtype='int64', length=4081),
#  'Calculation of median': Int64Index([7189041, 7189042, 7189043, 7189044, 7189045, 7189046, 7189047], dtype='int64'),
#  'Calculation of multiplying whole numbers by one decimal place': Int64Index([5365171, 5365172, 5365173, 5365174, 5365175, 5365176, 5365177,
#              5365178, 5365179, 5365180,
#              ...
#              5366499, 5366500, 5366501, 5366502, 5366503, 5366504, 5366505,
#              5366506, 5366507, 5366508],
#             dtype='int64', length=1338),
#  'Calculation of price increase, mark-up and interest': Int64Index([6062485, 6062486, 6062487, 6062488, 6062489, 6062490, 6062491,
#              6062492, 6062493, 6062494,
#              ...
#              6062818, 6062819, 6062820, 6062821, 6062822, 6062823, 6062824,
#              6062825, 6062826, 6062827],
#             dtype='int64', length=343),
#  'Center, circumference, radius, diameter': Int64Index([2843413, 2843414, 2843415, 2843416, 2843417, 2843418, 2843419,
#              2843420, 2843421, 2843422,
#              ...
#              2861149, 2861150, 2861151, 2861152, 2861153, 2861154, 2861155,
#              2861156, 2861157, 2861158],
#             dtype='int64', length=17746),
#  'Change symbols and do cross multiplication': Int64Index([6494652, 6494653, 6494654, 6494655, 6494656, 6494657, 6494658,
#              6494659, 6494660, 6494661,
#              ...
#              6497650, 6497651, 6497652, 6497653, 6497654, 6497655, 6497656,
#  'Column formulas and solve problems: x+a=b': Int64Index([4736479, 4736480, 4736481, 4736482, 4736483, 4736484, 4736485,
#              4736486, 4736487, 4736488,
#              ...
#              4739006, 4739007, 4739008, 4739009, 4739010, 4739011, 4739012,
#              4739013, 4739014, 4739015],
#             dtype='int64', length=2537),
#  'Columnar expressions of binary linear': Int64Index([7046272, 7046273, 7046274, 7046275, 7046276, 7046277, 7046278,
#              7046279, 7046280, 7046281,
#              ...
#              7047574, 7047575, 7047576, 7047577, 7047578, 7047579, 7047580,
#              7047581, 7047582, 7047583],
#             dtype='int64', length=1312),
#  'Columns of linear equations in two unknowns': Int64Index([7023936, 7023937, 7023938, 7023939, 7023940, 7023941, 7023942,
#              7023943, 7023944, 7023945,
#              ...
#              7024377, 7024378, 7024379, 7024380, 7024381, 7024382, 7024383,
#              7024384, 7024385, 7024386],
#             dtype='int64', length=451),
#  'Combination of consecutive divisions': Int64Index([1221524, 1221525, 1221526, 1221527, 1221528, 1221529, 1221530,
#              1221531, 1221532, 1221533,
#              ...
#              1239186, 1239187, 1239188, 1239189, 1239190, 1239191, 1239192,
#              1239193, 1239194, 1239195],
#             dtype='int64', length=17672),
#  'Combination of consecutive divisions: with brackets': Int64Index([6285533, 6285534, 6285535, 6285536, 6285537, 6285538, 6285539,
#              6285540, 6285541, 6285542,
#              ...
#              6288372, 6288373, 6288374, 6288375, 6288376, 6288377, 6288378,
#              6288379, 6288380, 6288381],
#             dtype='int64', length=2849),
#  'Combination of consecutive reductions': Int64Index([3108922, 3108923, 3108924, 3108925, 3108926, 3108927, 3108928,
#              3108929, 3108930, 3108931,
#              ...
#              3112384, 3112385, 3112386, 3112387, 3112388, 3112389, 3112390,
#              3112391, 3112392, 3112393],
#             dtype='int64', length=3472),
#  'Combination of continuous addition': Int64Index([6828632, 6828633, 6828634, 6828635, 6828636, 6828637, 6828638,
#              6828639, 6828640, 6828641,
#              ...
#              6832766, 6832767, 6832768, 6832769, 6832770, 6832771, 6832772,
#              6832773, 6832774, 6832775],
#             dtype='int64', length=4144),
#  'Combination of division and addition and subtraction: no parentheses': Int64Index([3351777, 3351778, 3351779, 3351780, 3351781, 3351782, 3351783,
#              3351784, 3351785, 3351786,
#              ...
#              3353929, 3353930, 3353931, 3353932, 3353933, 3353934, 3353935,
#              3353936, 3353937, 3353938],
#             dtype='int64', length=2162),
#  'Combination of division and addition and subtraction: parentheses': Int64Index([6291052, 6291053, 6291054, 6291055, 6291056, 6291057, 6291058,
#              6291059, 6291060, 6291061,
#              ...
#              6292998, 6292999, 6293000, 6293001, 6293002, 6293003, 6293004,
#              6293005, 6293006, 6293007],
#             dtype='int64', length=1956),
#  'Combination of multiplication and addition and subtraction: no parentheses': Int64Index([6288382, 6288383, 6288384, 6288385, 6288386, 6288387, 6288388,
#              6288389, 6288390, 6288391,
#              ...
#              6291042, 6291043, 6291044, 6291045, 6291046, 6291047, 6291048,
#              6291049, 6291050, 6291051],
#             dtype='int64', length=2670),
#  'Combination of multiplication and addition and subtraction: parentheses': Int64Index([6270139, 6270140, 6270141, 6270142, 6270143, 6270144, 6270145,
#              6270146, 6270147, 6270148,
#              ...
#              6272049, 6272050, 6272051, 6272052, 6272053, 6272054, 6272055,
#              6272056, 6272057, 6272058],
#             dtype='int64', length=1920),
#  'Combination of multiplication and division': Int64Index([3500121, 3500122, 3500123, 3500124, 3500125, 3500126, 3500127,
#              3500128, 3500129, 3500130,
#              ...
#              3527593, 3527594, 3527595, 3527596, 3527597, 3527598, 3527599,
#              3527600, 3527601, 3527602],
#             dtype='int64', length=27482),
#  'Combinations of consecutive multiplications: with brackets': Int64Index([6275177, 6275178, 6275179, 6275180, 6275181, 6275182, 6275183,
#              6275184, 6275185, 6275186,
#              ...
#              6279186, 6279187, 6279188, 6279189, 6279190, 6279191, 6279192,
#              6279193, 6279194, 6279195],
#             dtype='int64', length=4019),
#  'Common factor of bill of lading': Int64Index([6609419, 6609420, 6609421, 6609422, 6609423, 6609424, 6609425,
#              6609426, 6609427, 6609428,
#              ...
#              6615699, 6615700, 6615701, 6615702, 6615703, 6615704, 6615705,
#              6615706, 6615707, 6615708],
#             dtype='int64', length=6290),
#  'Common tangent application': Int64Index([7155692, 7155693, 7155694, 7155695, 7155696, 7155697, 7155698,
#              7155699, 7155700, 7155701,
#              ...
#              7156223, 7156224, 7156225, 7156226, 7156227, 7156228, 7156229,
#              7156230, 7156231, 7156232],
#             dtype='int64', length=541),
#  'Compare the number of points': Int64Index([3336583, 3336584, 3336585, 3336586, 3336587, 3336588, 3336589,
#              3336590, 3336591, 3336592,
#              ...
#              3343038, 3343039, 3343040, 3343041, 3343042, 3343043, 3343044,
#              3343045, 3343046, 3343047],
#             dtype='int64', length=6465),
#  'Comparison coefficient': Int64Index([6923805, 6923806, 6923807, 6923808, 6923809, 6923810, 6923811,
#              6923812, 6923813, 6923814,
#              ...
#              6925262, 6925263, 6925264, 6925265, 6925266, 6925267, 6925268,
#              6925269, 6925270, 6925271],
#             dtype='int64', length=1467),
#  'Comparison of multiple box plots': Int64Index([7197404, 7197405, 7197406, 7197407, 7197408], dtype='int64'),
#  'Comparison of multiple decimal places': Int64Index([1668140, 1668141, 1668142, 1668143, 1668144, 1668145, 1668146,
#              1668147, 1668148, 1668149,
#              ...
#              1683282, 1683283, 1683284, 1683285, 1683286, 1683287, 1683288,
#              1683289, 1683290, 1683291],
#             dtype='int64', length=15152),
#  'Comparison of the size of corners': Int64Index([2433391, 2433392, 2433393, 2433394, 2433395, 2433396, 2433397,
#              2433398, 2433399, 2433400,
#              ...
#              2456936, 2456937, 2456938, 2456939, 2456940, 2456941, 2456942,
#              2456943, 2456944, 2456945],
#             dtype='int64', length=23555),
#  'Comparison of the size of one decimal place 1': Int64Index([5307804, 5307805, 5307806, 5307807, 5307808, 5307809, 5307810,
#              5307811, 5307812, 5307813,
#              ...
#              5310968, 5310969, 5310970, 5310971, 5310972, 5310973, 5310974,
#              5310975, 5310976, 5310977],
#             dtype='int64', length=3174),
#              2294272, 2294273, 2294274,
#              ...
#              2299672, 2299673, 2299674, 2299675, 2299676, 2299677, 2299678,
#              2299679, 2299680, 2299681],
#             dtype='int64', length=5417),
#  '【基礎】分數的乘法': Int64Index([2284811, 2284812, 2284813, 2284814, 2284815, 2284816, 2284817,
#              2284818, 2284819, 2284820,
#              ...
#              2294255, 2294256, 2294257, 2294258, 2294259, 2294260, 2294261,
#              2294262, 2294263, 2294264],
#             dtype='int64', length=9454),
#  '【基礎】分數的乘法綜合習題': Int64Index([4246444, 4246445, 4246446, 4246447, 4246448, 4246449, 4246450,
#              4246451, 4246452, 4246453,
#              ...
#              4247802, 4247803, 4247804, 4247805, 4247806, 4247807, 4247808,
#              4247809, 4247810, 4247811],
#             dtype='int64', length=1368),
#  '【基礎】分數的加減應用': Int64Index([1628911, 1628912, 1628913, 1628914, 1628915, 1628916, 1628917,
#              1628918, 1628919, 1628920,
#              ...
#              1633306, 1633307, 1633308, 1633309, 1633310, 1633311, 1633312,
#              1633313, 1633314, 1633315],
#             dtype='int64', length=4405),
#  '【基礎】分數的大小比較 1': Int64Index([3249935, 3249936, 3249937, 3249938, 3249939, 3249940, 3249941,
#              3249942, 3249943, 3249944,
#              ...
#              3257697, 3257698, 3257699, 3257700, 3257701, 3257702, 3257703,
#              3257704, 3257705, 3257706],
#             dtype='int64', length=7772),
#  '【基礎】分數的比較大小': Int64Index([2105224, 2105225, 2105226, 2105227, 2105228, 2105229, 2105230,
#              2105231, 2105232, 2105233,
#              ...
#              2116249, 2116250, 2116251, 2116252, 2116253, 2116254, 2116255,
#              2116256, 2116257, 2116258],
#             dtype='int64', length=11035),
#  '【基礎】分數的約分與擴分': Int64Index([2258784, 2258785, 2258786, 2258787, 2258788, 2258789, 2258790,
#              2258791, 2258792, 2258793,
#              ...
#              2269583, 2269584, 2269585, 2269586, 2269587, 2269588, 2269589,
#              2269590, 2269591, 2269592],
#             dtype='int64', length=10809),
#  '【基礎】分數的累加': Int64Index([2405407, 2405408, 2405409, 2405410, 2405411, 2405412, 2405413,
#              2405414, 2405415, 2405416,
#              ...
#              2415358, 2415359, 2415360, 2415361, 2415362, 2415363, 2415364,
#              2415365, 2415366, 2415367],
#             dtype='int64', length=9961),
#  '【基礎】分數的除法': Int64Index([2245030, 2245031, 2245032, 2245033, 2245034, 2245035, 2245036,
#              2245037, 2245038, 2245039,
#              ...
#              2251023, 2251024, 2251025, 2251026, 2251027, 2251028, 2251029,
#              2251030, 2251031, 2251032],
#             dtype='int64', length=6003),
#  '【基礎】分數運算的應用問題': Int64Index([5209251, 5209252, 5209253, 5209254, 5209255, 5209256, 5209257,
#              5209258, 5209259, 5209260,
#              ...
#              5212024, 5212025, 5212026, 5212027, 5212028, 5212029, 5212030,
#              5212031, 5212032, 5212033],
#             dtype='int64', length=2783),
#  '【基礎】分數除以整數 1': Int64Index([4244680, 4244681, 4244682, 4244683, 4244684, 4244685, 4244686,
#              4244687, 4244688, 4244689,
#              ...
#              4246434, 4246435, 4246436, 4246437, 4246438, 4246439, 4246440,
#              4246441, 4246442, 4246443],
#             dtype='int64', length=1764),
#  '【基礎】分數除法的應用：平分和分裝': Int64Index([4572538, 4572539, 4572540, 4572541, 4572542, 4572543, 4572544,
#              4572545, 4572546, 4572547,
#              ...
#              4576621, 4576622, 4576623, 4576624, 4576625, 4576626, 4576627,
#              4576628, 4576629, 4576630],
#             dtype='int64', length=4093),
#  '【基礎】分配律的應用': Int64Index([5378852, 5378853, 5378854, 5378855, 5378856, 5378857, 5378858,
#              5378859, 5378860, 5378861,
#              ...
#              5383996, 5383997, 5383998, 5383999, 5384000, 5384001, 5384002,
#              5384003, 5384004, 5384005],
#             dtype='int64', length=5154),
#  '【基礎】判別 2、4、5 的倍數': Int64Index([2116259, 2116260, 2116261, 2116262, 2116263, 2116264, 2116265,
#              2116266, 2116267, 2116268,
#              ...
#              2125313, 2125314, 2125315, 2125316, 2125317, 2125318, 2125319,
#              2125320, 2125321, 2125322],
#             dtype='int64', length=9064),
#  '【基礎】判別 3、9、11 的倍數': Int64Index([2148326, 2148327, 2148328, 2148329, 2148330, 2148331, 2148332,
#              2148333, 2148334, 2148335,
#              ...
#              2158030, 2158031, 2158032, 2158033, 2158034, 2158035, 2158036,
#              2158037, 2158038, 2158039],
#             dtype='int64', length=9714),
#  '【基礎】判斷最簡根式': Int64Index([3663133, 3663134, 3663135, 3663136, 3663137, 3663138, 3663139,
#              3663140, 3663141, 3663142,
#              ...
#              3670759, 3670760, 3670761, 3670762, 3670763, 3670764, 3670765,
#              3670766, 3670767, 3670768],
#             dtype='int64', length=7636),
#  '【基礎】利用平方差公式有理化分母': Int64Index([6626971, 6626972, 6626973, 6626974, 6626975, 6626976, 6626977,
#              6626978, 6626979, 6626980,
#              ...
#              6631830, 6631831, 6631832, 6631833, 6631834, 6631835, 6631836,
#              6631837, 6631838, 6631839],
#             dtype='int64', length=4869),
#  '【基礎】利用標準分解式求最大公因數': Int64Index([3833768, 3833769, 3833770, 3833771, 3833772, 3833773, 3833774,
#              3833775, 3833776, 3833777,
#              ...
#              3841144, 3841145, 3841146, 3841147, 3841148, 3841149, 3841150,
#              3841151, 3841152, 3841153],
#             dtype='int64', length=7386),
#  '【基礎】利用畢氏定理求直角三角形的邊長 1': Int64Index([6557500, 6557501, 6557502, 6557503, 6557504, 6557505, 6557506,
#              6557507, 6557508, 6557509,
#              ...
#              6566899, 6566900, 6566901, 6566902, 6566903, 6566904, 6566905,
#              6566906, 6566907, 6566908],
#             dtype='int64', length=9409),
#  '【基礎】利用畢氏定理求直角三角形的邊長 2': Int64Index([6504385, 6504386, 6504387, 6504388, 6504389, 6504390, 6504391,
#              6504392, 6504393, 6504394,
#              ...
#              6512754, 6512755, 6512756, 6512757, 6512758, 6512759, 6512760,
#              6512761, 6512762, 6512763],
#             dtype='int64', length=8379),
#  ...}

# %%
merge_df_LogProblem_InfoUser_InfoContent.groupby(['content_pretty_name','uuid']) \
        .agg({'uuid':'count', 'total_sec_taken':'mean','total_attempt_cnt':'mean'}) \
        .rename(columns={'uuid':'count','total_sec_taken':'total sec taken'}) \
        .reset_index()
# Out:
#        content_pretty_name                                          uuid  \
# 0                  時間的基本概念  +1EtHQKEVT+ebZYjmLpyd9rQR13/bwmHZENZ8p6qxvI=
# 1                  時間的基本概念  +1MK7AXO4FAPqL5O37KhLqa1f7VAlhUhMaViuLs/QE0=
# 2                  時間的基本概念  +4WlShSd4sqkedrbj6w1KoUcK1kd/uudseuccMD1rVc=
# 3                  時間的基本概念  +4XtOUFmbVptlLlMaZLqAwt3LF2VBoU7pgIcCpKuUKM=
# 4                  時間的基本概念  +CpT30GOm/YPy5sQAYy8DwXbJ84W3DHy+x6I333nncI=
# ...                    ...                                           ...
# 717756         體積：立方公分綜合習題  z+wkKkqsaED6QOJZLc8dIgP4S3nuPp1JykxGhCaGE7E=
# 717757         體積：立方公分綜合習題  z4UwNA5DG4o3rwth2Hm4Ekz4MCndmlGz/k1+s09WFSQ=
# 717758         體積：立方公分綜合習題  zA9qxBneOkZzdikrzs8BrB7zq2DCfBzLZqV6sOqlZ2o=
# 717759         體積：立方公分綜合習題  zlbXZ3rS8iX0J+O1igq/rMmP0yxAw52Pg/7+6zoRad0=
# 717760         體積：立方公分綜合習題  zoMGJsjOUeOW2Fm65e/QBq8K6ZGSO2MvqAogq1wjRwA=
#
#         count  total sec taken  total_attempt_cnt
# 0           3        12.000000           1.000000
# 1           2        25.000000           3.000000
# 2          12        10.916667           1.416667
# 3          14         9.214286           1.428571
# 4          10        11.200000           1.100000
# ...       ...              ...                ...
# 717756     11        13.454545           1.000000
# 717757      4        36.500000           3.500000
# 717758     38        18.631579           1.447368
# 717759     36        14.444444           1.166667
# 717760     28        32.428571           2.392857
#
# [717761 rows x 5 columns]

# %%
raw_df_LogProblem.shape
# Out:
# (16217311, 14)

# %%
pd.pivot_table(merge_df_LogProblem_InfoUser_InfoContent,
                        values = ['total_sec_taken'],
                        index = ['content_pretty_name','uuid'],
                        columns = [],aggfunc=[np.mean], 
                        margins=True)
# Out:
#                                                                                               mean
#                                                                                    total_sec_taken
# content_pretty_name                   uuid
# A brief note on algebraic expressions +2ThnpLSMJmhHRtF+eeCXVSnqgkRfjzyz8fip0NcpGA=       15.000000
#                                       +2abMV9txxcfEweYKMsmCCuGOAULfHyrW1x30xcaJNc=       15.000000
#                                       +3PS3StJNpyUoL1nu0+OqGfGtJ9f6K1ZSPM0HPLd+R0=       17.600000
#                                       +63OvIhAIlYhZ3fOUlKIfSKRJc9ktfQly9JRrk/Sznw=       11.400000
#                                       +FcHdDAsqZphfzlf5Crh+O79NQJHqKoK65BwBj12aiQ=       18.000000
# ...                                                                                            ...
# 點與線、線與線距離                             zjBkUBYx8nQw8y2HW4JIOIbGFNCix59AWmVN4mghR+Q=       12.000000
#                                       zkyr61bZqL5GzwOTCmriswdGIWGoEtB4kKjsO30iJ9U=       10.021739
#                                       zpdQm4TAvVRzoBDPeoRFh2pwzPzWIKPvMBPLUcTgd9w=       17.000000
#                                       zv6KHHgAdCT+6qjbcKkQLhT4gjMq9u/PwTBpVGBoPi4=        0.000000
# All                                                                                      42.897987
#
# [768273 rows x 1 columns]

# %%
y = pd.pivot_table(merge_df_LogProblem_InfoUser_InfoContent[merge_df_LogProblem_InfoUser_InfoContent['uuid']=='+1EtHQKEVT+ebZYjmLpyd9rQR13/bwmHZENZ8p6qxvI='],
                        values = ['total_sec_taken'],
                        index = ['content_pretty_name'],
                        columns = ['is_correct'],aggfunc=[np.mean], 
                        margins=True)

# %%
#plt.figure(figsize=(100,50))
#plt.barh(y)
y.plot(kind='barh',figsize=(10,50))

# %%
y.columns
# Out:
# MultiIndex([('mean', 'total_sec_taken', False),
#             ('mean', 'total_sec_taken',  True),
#             ('mean', 'total_sec_taken', 'All')],
#            names=[None, None, 'is_correct'])

# %%
content_pretty_name_total_sec_taken = pd.pivot_table(merge_df_LogProblem_InfoUser_InfoContent,
                        values = ['total_sec_taken'],
                        index = ['content_pretty_name'],
                        columns = [],aggfunc=[np.mean], 
                        margins=True)

# %%
x = pd.pivot_table(merge_df_LogProblem_InfoUser_InfoContent,
                        values = ['total_sec_taken'],
                        index = ['uuid','content_pretty_name'],
                        columns = [],aggfunc=[np.mean], 
                        margins=True)

# %%
x.plot(kind='bar')

# %%
df_InfoUser.columns
# Out:
# Index(['gender', 'points', 'badges_cnt', 'first_login_date_TW', 'user_grade',
#        'user_city', 'has_teacher_cnt', 'is_self_coach', 'has_student_cnt',
#        'belongs_to_class_cnt', 'has_class_cnt'],
#       dtype='object')

# %%
df_InfoUser.pivot_table('points', index='datetime', columns='gender', aggfunc='sum')
# Out:
# gender         female       male  unspecified
# datetime
# 2018-08-01  2161065.0  2549149.0     574757.0
# 2018-08-02  1119990.0  2541848.0     730106.0
# 2018-08-03  2206167.0  2431055.0    1514245.0
# 2018-08-04   999735.0  1880218.0     146625.0
# 2018-08-05   792624.0   743131.0     331981.0
# ...               ...        ...          ...
# 2019-07-27   191918.0   213999.0     137804.0
# 2019-07-28   136311.0   210128.0     164306.0
# 2019-07-29   935737.0  1669339.0     691670.0
# 2019-07-30   967786.0   396363.0     239041.0
# 2019-07-31   137741.0    57149.0     168483.0
#
# [365 rows x 3 columns]

# %%
sns.set()  # use Seaborn styles
df_InfoUser.pivot_table('points', index='datetime', columns='gender', aggfunc='sum').plot()
plt.ylabel('total points contributed per year');

# %% [markdown]
# With a simple pivot table and plot() method, we can immediately see the annual trend in births by gender. By eye, it appears that over the past 50 years male births have outnumbered female births by around 5%.

# %%
content_pretty_name_total_sec_taken.columns
# Out:
# MultiIndex([('mean', 'total_sec_taken')],
#            )

# %%
plt.figure(figsize=(16,9))
content_pretty_name_total_sec_taken.plot(kind='barh',figsize=(192,108))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-2abe7fa6688f> in <module>
#       1 plt.figure(figsize=(16,9))
# ----> 2 content_pretty_name_total_sec_taken.plot(kind='barh',figsize=(192,108))
#
# NameError: name 'content_pretty_name_total_sec_taken' is not defined

# %% [markdown]
# ### 3.2 Scaling and Normalization

# %%
sns.distplot(df_InfoUser.points)

# %%
sns.distplot(df_InfoUser.badges_cnt)

# %%
sns.distplot(df_InfoUser.is_teacher_cnt)

# %% [markdown]
# ### 3.3 Parsing Dates

# %%
for index, row in df_LogProblem.iterrows():
    row['datetime'] = datetime.strptime(row['timestamp_TW'], '%Y-%m-%d %H:%M:%S %Z')

# %%
df_LogProblem.head()

# %%
# print the first few rows of the date column
print(df_LogProblem['date_TW'].head())

# %% [markdown]
# ### Handling Categorical Variables

# %% [markdown]
# Next, we obtain a list of all of the categorical variables in the training data.
#
# We do this by checking the data type (or dtype) of each column. The object dtype indicates a column has text (there are other things it could theoretically be, but that's unimportant for our purposes). For this dataset, the columns with text indicate categorical variables.

# %% [markdown]
# So far, we have only been working with numerical values. However, it is not
# uncommon that real-world datasets contain one or more categorical feature columns.
# In this section, we will make use of simple yet effective examples to see how we deal
# with this type of data in numerical computing libraries.

# %%
# Get list of categorical variables
s = (df_InfoUser.dtypes == 'object')
object_cols = list(s[s].index)

print("df_InfoUser Categorical variables:")
print(object_cols)

# Get list of categorical variables
s = (df_InfoContent.dtypes == 'object')
object_cols = list(s[s].index)

print("df_InfoContent Categorical variables:")
print(object_cols)

# Get list of categorical variables
s = (df_LogProblem.dtypes == 'object')
object_cols = list(s[s].index)

print("df_LogProblem Categorical variables:")
print(object_cols)

# %% [markdown]
# #### Label Encoding - Mapping ordinal features
# To make sure that the learning algorithm interprets the ordinal features correctly,
# we need to convert the categorical string values into integers. Unfortunately, there is
# no convenient function that can automatically derive the correct order of the labels
# of our size feature, so we have to define the mapping manually. In the following
# simple example, let's assume that we know the numerical difference between
# features, for example, hard = normal + 1 = easy + 2 = unset + 3.

# %% [markdown]
# - Info Content

# %%
difficulty_mapping = {
    'easy': 1,
    'normal': 2,
    'hard': 3,
    'unset': 0
}
learning_stage_mapping = {
    'elementary': 1,
    'junior': 2,
    'senior': 3
}

# %%
df_InfoContent['difficulty'] = df_InfoContent['difficulty'].map(difficulty_mapping)
df_InfoContent['learning_stage'] = df_InfoContent['learning_stage'].map(learning_stage_mapping)

# %%
df_InfoContent.head()

# %% [markdown]
# - Info User

# %% [markdown]
# ### One-hot encoding - Nominal
# One-hot encoding creates new columns indicating the presence (or absence) of each possible value in the original data. To understand this, we'll work through an example.

# %% [markdown]
# - Info User

# %%
pd.get_dummies(df_InfoUser.gender, prefix='gender').iloc[:,:-1]

# %%
pd.get_dummies(df_InfoUser.user_city, prefix='user_city').iloc[:,:-1]

# %% [markdown]
# - Log Problem

# %%
pd.get_dummies(df_LogProblem.is_upgrade, prefix='is_upgrade').iloc[:,1:]

# %% [markdown]
# ## Splitting Test set
#
# A common first step to training a model is to divide up the dataset into training and validation data. This allows you to use a portion of the data to train the model and a portion of the data to test the model. If you used all your data to train the model, you wouldn't have a way to estimate how well it would actually perform against data the model has not yet seen. A benefit of the scikit-learn library is that it provides a method specifically for splitting a dataset into training and test data.

# %%
train, test = train_test_split(clean, test_size=0.3, random_state=4444)

print "Training Size: ", train.shape[0]
print "Test Size:     ", test.shape[0]

# %%
fig, ax = plt.subplots()
ax.plot(df_InfoContent['ucid'], df_InfoContent['level1_id'], label="dog")
ax.plot(df_InfoContent['ucid'], df_InfoContent['level2_id'], label="cat")
ax.plot(df_InfoContent['ucid'], df_InfoContent['level3_id'], label="cat")
ax.plot(df_InfoContent['ucid'], df_InfoContent['level4_id'], label="cat")
ax.legend()

plt.show()
plt.savefig('a.png')

# %%
plt.scatter(df_LogProblem.uuid[90:100], df_LogProblem.ucid[90:100])
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
for x in df_LogProblem.uuid.unique():
    plt.plot(df_LogProblem.ucid[df_LogProblem.uuid==x])

# %%
df_LogProblem.uuid.unique()

# %%
df_LogProblem.ucid[df_LogProblem.uuid=="AAITw26FaJFdy0VfpYXlUhEpJnYcjEucad09AXqKmUE="]

# %%
df_LogProblem[df_LogProblem['uuid'] == "AAITw26FaJFdy0VfpYXlUhEpJnYcjEucad09AXqKmUE="]

# %%
plt.scatter(df_LogProblem.uuid[df_LogProblem['uuid'] == "AAITw26FaJFdy0VfpYXlUhEpJnYcjEucad09AXqKmUE="], df_LogProblem.upid[df_LogProblem['uuid'] == "AAITw26FaJFdy0VfpYXlUhEpJnYcjEucad09AXqKmUE="])
plt.title('Scatter plot pythonspot.com')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# ## 4. Baseline Modeling

# %% [markdown]
# ## 5. Secondary Modeling

# %% [markdown]
# ## 6. Communicating Results
#
# In my mind there are two directions your data science project can go: the data science product and the data science report.
#
# First, you can create a data science product. Getting your model into production is, once again, a topic in itself. To begin with, you will need to move code from your Jupyter Notebook to scripts. In most firms, the data scientist will be working along side the software engineering team to write this code. The model will first need to be pickled and this can be accomplished with Scikit-Learn’s Joblib. Then we can use Flask and Heroku to create an application for your model. In this tutorial, I have elected to forgo this method. Developing data science products is a very useful skill and I myself am diving deeper into these processes. I encourage you to do the same!
#
# Alternatively to the data product, you can create a data science report. You can showcase your results to the firm with a presentation and offer a technical overview on the process. Remember to keep your audience in mind. If you are presenting results to a room full of data scientists, go into detail. If you are advising the sales team, don’t talk about the universal approximation theorem for 45 minutes before explaining your results. To me, a data science report is a bit like a mini thesis. You are presenting a paper, which your peers (and bosses) will scrutinize and which you need to defend.
#
# If your company allows you to publish the results, I would recommend bringing your presentation to a data science meetup. Feedback on your project for the data science community at large is always a great learning experience. Check out PyData videos on YouTube if you want to see some excellent presentations. Additionally, write a blog post and push your code to GitHub so the data science community can learn from your success. Communicating your results is a part of the scientific process so don’t keep your findings hidden away!

# %% [markdown]
# ## 7. Conclusion
# I hope this workflow and mini-project was helpful for aspiring data scientists and people who work with data scientists. Like I mentioned a million times, there is a lot of detail that I glossed over here. Let me know if you have any questions or comments!

# %% [markdown]
# ## 8. Resources
#
# P. J. Chen, M. E. Hsieh, T. Y. Tsai. Junyi Online Learning Dataset: A large-scale public online learning activity dataset from elementary to senior high school students., 2020. Available from https://www.kaggle.com/junyiacademy/learning-activity-public-dataset-by-junyi-academy".
