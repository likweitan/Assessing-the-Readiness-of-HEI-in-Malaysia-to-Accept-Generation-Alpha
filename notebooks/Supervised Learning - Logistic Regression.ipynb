# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O
import matplotlib.pyplot as plt

# %%
# %%time
info_content_raw_df = pd.read_csv('data/Info_Content_Edited.csv')
#info_userdata_raw_df = pd.read_csv('data/Info_UserData.csv', index_col='uuid')
log_problem_raw_df = pd.read_csv('data/Log_Problem_Edited.csv')
# Out:
# Wall time: 14 s

# %%
info_content_df = info_content_raw_df.copy()
log_problem_df = log_problem_raw_df.copy()

# %%
info_content_df.head()
# Out:
#    Unnamed: 0                                          ucid  \
# 0           0  odIwFdIiecFwVUAEEV40K3MSuCSlIZkbq92Zp9tkZq8=
# 1           1  dfeeBaa8zDhWS6nu7zeXKwLyi4zqEajI3tJM9/fSBPM=
# 2           2  C2AT0OBTUn+PRxEVd39enhW/DJtka1Tk90DUAR6yVdA=
# 3           3  jZvYpEa6VB/WrlKKmQHnfbv/xJ4OypBzq0epVcn500Q=
# 4           4  M+UxJPgRIW57a0YS3eik8A9YDj+AwaMpTa5yWYn/kAw=
#
#   content_pretty_name content_kind difficulty subject learning_stage  \
# 0       【基礎】怎樣解題：數量關係     Exercise       easy    math     elementary
# 1          【基礎】和差問題 1     Exercise       easy    math     elementary
# 2          【基礎】雞兔問題 1     Exercise       easy    math     elementary
# 3          【基礎】年齡問題 1     Exercise       easy    math     elementary
# 4            【基礎】追趕問題     Exercise       easy    math     elementary
#
#                                       level1_id  \
# 0  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# 1  aH0Dz0KdH9gio7rrcGRHvrmd9vcd/0WJbeEFB7qeUKA=
# ...

# %%
log_problem_df.head()
# Out:
#    Unnamed: 0             timestamp_TW  \
# 0           0  2018-09-28 20:00:00 UTC
# 1           1  2018-09-28 10:15:00 UTC
# 2           2  2018-09-05 20:00:00 UTC
# 3           3  2018-09-14 16:30:00 UTC
# 4           4  2018-09-13 16:00:00 UTC
#
#                                            uuid  \
# 0  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 1  0+VU/Zb0Q96uoByuRhl7r9bJuJO6CKWpsmNMEuijSzc=
# 2  g8DnYvIqpolw10XlwWeIWv6NbDPByUbmgH8EshJqBns=
# 3  kSyUTFlepsYUD723IPL/jEZ520xaKbscrBmNtBUFR1o=
# 4  XMFbFA7C49+LRhUddhelfPpA6F5dbOoxeyL3eYbuTlY=
#
#                                            ucid  problem_number  \
# 0  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=               2
# 1  /d39FzqaM3PZzpoMXxA80PMICsVhzfL6MGSCqZtsQOo=               6
# 2  YuGOmB+frbM8rfAa0RJE882R+IoMf9N89OiVqLbAHBw=               4
# 3  BG1RsWojzEHzV28RBm/1iKi1NyZgDcDomLYEJSV6lmo=               3
# 4  qPHR8aBqOhKij9IS/Y8IR8prwWruoDBGU1tVUhXDJkE=              12
#
# ...
