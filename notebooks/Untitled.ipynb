# %%
import pandas as pd

# %%
# %%time
merge_df = pd.read_csv('../data/raw/log_problem_.csv')
# Out:
# Wall time: 39.4 s

# %%
merge_df.columns
# Out:
# Index(['timestamp_TW', 'uuid', 'ucid', 'upid', 'problem_number',
#        'exercise_problem_repeat_session', 'is_correct', 'total_sec_taken',
#        'total_attempt_cnt', 'used_hint_cnt', 'is_hint_used', 'is_downgrade',
#        'is_upgrade', 'level'],
#       dtype='object')

# %%
merge_df['datetime_attempt'] = pd.to_datetime(merge_df['timestamp_TW'], format='%Y-%m-%d %H:%M:%S %Z')

# %%
merge_df['datetime_attempt'].describe()
# Out:
# count                      16217311
# unique                        30507
# top       2019-03-19 16:30:00+00:00
# freq                           7660
# first     2018-08-01 07:45:00+00:00
# last      2019-08-01 00:00:00+00:00
# Name: datetime_attempt, dtype: object

# %%
# scale down some records
merge_df = merge_df[merge_df['datetime_attempt'] < '2018-12-01']

# %%
merge_df.columns
# Out:
# Index(['timestamp_TW', 'uuid', 'ucid', 'upid', 'problem_number',
#        'exercise_problem_repeat_session', 'is_correct', 'total_sec_taken',
#        'total_attempt_cnt', 'used_hint_cnt', 'is_hint_used', 'is_downgrade',
#        'is_upgrade', 'level', 'datetime_attempt'],
#       dtype='object')

# %%
merge_df = merge_df.drop(columns=['datetime_attempt'])

# %%
merge_df.columns
# Out:
# Index(['timestamp_TW', 'uuid', 'ucid', 'upid', 'problem_number',
#        'exercise_problem_repeat_session', 'is_correct', 'total_sec_taken',
#        'total_attempt_cnt', 'used_hint_cnt', 'is_hint_used', 'is_downgrade',
#        'is_upgrade', 'level'],
#       dtype='object')

# %%
merge_df.head()
# Out:
#                  timestamp_TW                                          uuid  \
# 6814  2018-09-28 20:00:00 UTC  Kpq2q+eKw/O+6/jLs3XJosgmI7weEJxJZdnkKTbbF8I=
# 6815  2018-09-28 10:15:00 UTC  0+VU/Zb0Q96uoByuRhl7r9bJuJO6CKWpsmNMEuijSzc=
# 6816  2018-09-05 20:00:00 UTC  g8DnYvIqpolw10XlwWeIWv6NbDPByUbmgH8EshJqBns=
# 6817  2018-09-14 16:30:00 UTC  kSyUTFlepsYUD723IPL/jEZ520xaKbscrBmNtBUFR1o=
# 6818  2018-09-13 16:00:00 UTC  XMFbFA7C49+LRhUddhelfPpA6F5dbOoxeyL3eYbuTlY=
#
#                                               ucid  \
# 6814  Ps4dfShfpeMF3VG030HqZ2bsbD7PaVxvJYFTtroeSzQ=
# 6815  /d39FzqaM3PZzpoMXxA80PMICsVhzfL6MGSCqZtsQOo=
# 6816  YuGOmB+frbM8rfAa0RJE882R+IoMf9N89OiVqLbAHBw=
# 6817  BG1RsWojzEHzV28RBm/1iKi1NyZgDcDomLYEJSV6lmo=
# 6818  qPHR8aBqOhKij9IS/Y8IR8prwWruoDBGU1tVUhXDJkE=
#
#                                               upid  problem_number  \
# 6814  ZmKEZ0F2WFqhlL7KFfJcHEnZCZu0e4p+CVG5rSlyKYk=               2
# ...

# %%
merge_df.sort_values('timestamp_TW')
# Out:
#                      timestamp_TW  \
# 13311409  2018-08-01 07:45:00 UTC
# 8372688   2018-08-01 07:45:00 UTC
# 9867905   2018-08-01 07:45:00 UTC
# 138933    2018-08-01 07:45:00 UTC
# 11669798  2018-08-01 07:45:00 UTC
# ...                           ...
# 11526146  2018-11-30 23:45:00 UTC
# 11526557  2018-11-30 23:45:00 UTC
# 15227626  2018-11-30 23:45:00 UTC
# 2129509   2018-11-30 23:45:00 UTC
# 633527    2018-11-30 23:45:00 UTC
#
#                                                   uuid  \
# 13311409  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 8372688   U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 9867905   U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 138933    U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 11669798  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# ...                                                ...
# 11526146  WaEHWxI492MKoHqrIzI/CqYe93ShuQPYyKeNh4+2YTA=
# 11526557  PgrCem2xSJt2NmrufHdvoak/HJRdkMUiZnq+DlSagn0=
# ...

# %%
merge_df.to_csv('../data/raw/Log_Problem.csv')
