# %%
import pandas as pd

# %%
# %%time
merge_df = pd.read_csv('../data/raw/log_problem.csv')
# Out:
# Wall time: 40 s

# %%
merge_df.columns
# Out:
# Index(['timestamp_TW', 'uuid', 'ucid', 'upid', 'problem_number',
#        'exercise_problem_repeat_session', 'is_correct', 'total_sec_taken',
#        'total_attempt_cnt', 'used_hint_cnt', 'is_hint_used', 'is_downgrade',
#        'is_upgrade', 'level'],
#       dtype='object')

# %%
merge_df['timestamp_TW'] = pd.to_datetime(merge_df['timestamp_TW'], format='%Y-%m-%d %H:%M:%S %Z')
merge_df = merge_df.rename(columns = {'timestamp_TW':'datetime_attempt'})

# %%
merge_df['datetime_attempt'].describe()
# Out:
# count                      16217311
# unique                        30507
# top       2019-03-19 16:30:00+00:00
# freq                           7660
# first     2018-08-01 07:45:00+00:00
# last      2019-08-01 00:00:00+00:00
# Name: datetime_attempt, dtype: object

# %%
merge_df.sort_values('datetime_attempt')
# Out:
#                   datetime_attempt  \
# 105021   2018-08-01 07:45:00+00:00
# 11669798 2018-08-01 07:45:00+00:00
# 3768239  2018-08-01 07:45:00+00:00
# 10163558 2018-08-01 07:45:00+00:00
# 8372688  2018-08-01 07:45:00+00:00
# ...                            ...
# 5351619  2019-08-01 00:00:00+00:00
# 8225534  2019-08-01 00:00:00+00:00
# 14727695 2019-08-01 00:00:00+00:00
# 13201613 2019-08-01 00:00:00+00:00
# 15112240 2019-08-01 00:00:00+00:00
#
#                                                   uuid  \
# 105021    U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 11669798  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 3768239   U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 10163558  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 8372688   U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# ...                                                ...
# 5351619   liamj78o0Ae2wnaS0hq7LUfSTsp3xB6HEcffaKBUzGc=
# 8225534   DndeYzUnQn5RMFK82bE5EUK7UeWFnO3VgT7uAuluqTM=
# ...

# %%
merge_df.sort_values('datetime_attempt', ascending=False)
# Out:
#                   datetime_attempt  \
# 261862   2019-08-01 00:00:00+00:00
# 369192   2019-08-01 00:00:00+00:00
# 13403866 2019-08-01 00:00:00+00:00
# 367795   2019-08-01 00:00:00+00:00
# 13180283 2019-08-01 00:00:00+00:00
# ...                            ...
# 13311409 2018-08-01 07:45:00+00:00
# 3768239  2018-08-01 07:45:00+00:00
# 10163558 2018-08-01 07:45:00+00:00
# 11669798 2018-08-01 07:45:00+00:00
# 2146461  2018-08-01 07:45:00+00:00
#
#                                                   uuid  \
# 261862    liamj78o0Ae2wnaS0hq7LUfSTsp3xB6HEcffaKBUzGc=
# 369192    liamj78o0Ae2wnaS0hq7LUfSTsp3xB6HEcffaKBUzGc=
# 13403866  hCyJTrhgUprNNWpJYKPcyHIxDHnbW91tv0OEM0wXSuI=
# 367795    hCyJTrhgUprNNWpJYKPcyHIxDHnbW91tv0OEM0wXSuI=
# 13180283  hCyJTrhgUprNNWpJYKPcyHIxDHnbW91tv0OEM0wXSuI=
# ...                                                ...
# 13311409  U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# 3768239   U+lqK/FKWkPuoNUM1AbGyrKZfXeQrRRoKOToKrjqDt4=
# ...
